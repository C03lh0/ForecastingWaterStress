# %% [markdown]
# # Classification and Forecasting of Water Stress in Tomato Plants using Bioristor Data
#
# ## Manuele Bettelli, Filippo Vurro, Riccardo Pecori, Michela Janni,Nicola Coppedè, Andrea Zappettini, Daniele Tessera
#
# ## Code Version 1.0
#
# ### For more info: daniele.tessera@unicatt.it

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# Disable GPU since is not supported by LSTM layers
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import StandardScaler
from sklearn.utils.class_weight import compute_class_weight
from sklearn.model_selection import KFold, StratifiedKFold

from util import plotPlant, getLags, getTensors

# %%
loadNNfromFile=True

# %%
binlabels = ['Not Stressed', 'Stressed']

# %%
rawdata = pd.read_csv('AI_Pecori15min - dati grezzi - TOMATO.csv', sep=';', decimal=',')

# %%
rawdata.head()
# Out:
#         Day   Exp Plant Species    label       Rds      DIgs        tds  \
# 0  0.014773  IMEM     A  TOMATO  healthy  0.066654  0.000002  60.524727
# 1  0.034656  IMEM     A  TOMATO  healthy  0.068223  0.000002  61.474049
# 2  0.054543  IMEM     A  TOMATO  healthy  0.070111  0.000002  62.109619
# 3  0.074422  IMEM     A  TOMATO  healthy  0.072093  0.000002  62.563367
# 4  0.094310  IMEM     A  TOMATO  healthy  0.073950  0.000002  62.950393
#
#          tgs  dRds  dRgs  dtds  dtgs  SRds  SDIgs  Stds  Stgs
# 0  22.949897   NaN   NaN   NaN   NaN   NaN    NaN   NaN   NaN
# 1  23.162453   NaN   NaN   NaN   NaN   NaN    NaN   NaN   NaN
# 2  23.373160   NaN   NaN   NaN   NaN   NaN    NaN   NaN   NaN
# 3  23.598323   NaN   NaN   NaN   NaN   NaN    NaN   NaN   NaN
# 4  23.833428   NaN   NaN   NaN   NaN   NaN    NaN   NaN   NaN

# %%
rawdata.drop(['dRds', 'dRgs', 'dtds', 'dtgs', 'SRds', 'SDIgs', 'Stds', 'Stgs'], axis=1, inplace=True)
rawdata.label.astype('category');

# %%
rawdata.describe()
# Out:
#                 Day           Rds          DIgs           tds           tgs
# count  16418.000000  15653.000000  1.565300e+04  15653.000000  15653.000000
# mean      12.704003      0.091688  2.682442e-06    102.672955     30.155597
# std        7.838070      0.062765  1.652804e-06     74.559961     12.731754
# min        0.010829      0.000014 -1.670000e-09     10.053095      5.401225
# 25%        5.990456      0.043679  1.690000e-06     58.609145     24.704744
# 50%       11.808032      0.084107  2.750000e-06     87.527876     27.921203
# 75%       19.543817      0.128386  3.810000e-06    125.511300     31.476546
# max       28.331003      0.735517  1.650500e-05    905.024130    176.411750

# %%
rawdata[['Exp', 'Plant']].value_counts()
# Out:
# Exp    Plant
# ALSIA  A        1292
#        B        1292
#        C        1292
#        D        1292
#        E        1292
#        G        1292
# IMEM   A        1238
#        B        1238
#        C        1238
#        D        1238
#        E        1238
#        F        1238
#        G        1238
# dtype: int64

# %%
out = rawdata['label'].value_counts()
labs = []
s = sum(out)/100

for i in range(len(out)):
    labs.append(f"{out.index[i]} : {out[i]} ({out[i]/s:.2f}%)")
    
plt.figure(figsize=(10,5) )
plt.pie(out, labels = labs, colors=['green', 'gray', 'red', 'blue'], textprops={'fontsize': 18});
plt.savefig('label_pie.png')

# %%
rawdata[['Exp', 'Plant']].value_counts()/4/24
# Out:
# Exp    Plant
# ALSIA  A        13.458333
#        B        13.458333
#        C        13.458333
#        D        13.458333
#        E        13.458333
#        G        13.458333
# IMEM   A        12.895833
#        B        12.895833
#        C        12.895833
#        D        12.895833
#        E        12.895833
#        F        12.895833
#        G        12.895833
# dtype: float64

# %% [markdown]
# ## Data interpolation

# %%
plotPlant(rawdata, 'IMEM', 'E', 'Rds', nsteps=4, figSize=(15,5))
plotPlant(rawdata, 'IMEM', 'E', 'Rds', figSize=(12,5))

# %%
for target in ['Rds', 'DIgs', 'tds', 'tgs']:
    nNa = rawdata[target].isna().sum() 
    print(f"Number of N.A. observations for {target:7s} : {nNa:4d} ( {nNa/rawdata.shape[0]*100:.2f}% )")
# Out:
# Number of N.A. observations for Rds     :  765 ( 4.66% )
# Number of N.A. observations for DIgs    :  765 ( 4.66% )
# Number of N.A. observations for tds     :  765 ( 4.66% )
# Number of N.A. observations for tgs     :  765 ( 4.66% )

# %%
rawdata[rawdata.label=='healthy']['Rds'].hist(bins=100);

# %%
dataInterp = rawdata.interpolate(method='from_derivatives')

# %%
dataInterp.describe()
# Out:
#                 Day           Rds          DIgs           tds           tgs
# count  16418.000000  16418.000000  1.641800e+04  16418.000000  16418.000000
# mean      12.704003      0.093187  2.658791e-06    101.889569     30.311046
# std        7.838070      0.066205  1.652472e-06     73.470747     12.809647
# min        0.010829      0.000014 -1.670000e-09     10.053095      5.401225
# 25%        5.990456      0.044016  1.650000e-06     58.591125     24.743876
# 50%       11.808032      0.084146  2.730000e-06     86.504940     27.956687
# 75%       19.543817      0.129811  3.790000e-06    124.623170     31.521486
# max       28.331003      0.735517  1.650500e-05    905.024130    176.411750

# %%
df = dataInterp.copy();

df['DIgs']=1000000*df['DIgs']

selection = ['Rds', 'DIgs','tds', 'tgs']
unit = [None, '$\mu$A','s','s']

# selection = ['Rds', tds]

# fig, axes = plt.subplots(1, len(selection))
plt.figure(figsize=(14,6))

for i, col in enumerate(selection):
    plt.subplot(1,len(selection), i+1)
    ax = sns.boxplot(y=df[col], color='azure')
    if unit[i] is not None:
        if i==1:
            ax.set_title(r"$\Delta$Igs ($\mu$A) ")
        else:
            ax.set_title(f"{col} ({unit[i]})")
    else:
        ax.set_title(f"{col}")
        
    ax.set_ylabel("")

plt.savefig('summary.png')
plt.show();

# %%
# FIX unfeasible negative values
dataInterp.DIgs[dataInterp.DIgs<0]=0
dataInterp.describe()
# dataInterp.to_csv('AI_Pecori15min - dati grezzi - interpolated.csv')
# Out:
# <ipython-input-17-00a0b1fe7332>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataInterp.DIgs[dataInterp.DIgs<0]=0
#                 Day           Rds          DIgs           tds           tgs
# count  16418.000000  16418.000000  16418.000000  16418.000000  16418.000000
# mean      12.704003      0.093187      0.000003    101.889569     30.311046
# std        7.838070      0.066205      0.000002     73.470747     12.809647
# min        0.010829      0.000014      0.000000     10.053095      5.401225
# 25%        5.990456      0.044016      0.000002     58.591125     24.743876
# 50%       11.808032      0.084146      0.000003     86.504940     27.956687
# 75%       19.543817      0.129811      0.000004    124.623170     31.521486
# max       28.331003      0.735517      0.000017    905.024130    176.411750

# %% [markdown]
# ### Plot interpolated data

# %%
exp = 'IMEM'
plant='E'

plt.figure(figsize=(24,16));

plotPlant(rawdata, exp, plant, 'Rds', dataInterp=dataInterp, figSize=(10,5));
plt.savefig('interpolation.png')
# plotPlant(rawdata, exp, plant, 'tds', dataInterp=dataInterp, figSize=(10,5))
# plotPlant(rawdata, exp, plant, 'tgs', dataInterp=dataInterp, figSize=(10,5))

# %%
# Plot a parameter for all plants

target='Rds'

for e in rawdata.Exp.unique():
    for p in rawdata.Plant[rawdata.Exp==e].unique():
        plotPlant(rawdata, e, p, target, dataInterp=dataInterp, figSize=(15,5))

# %% [markdown]
# ## Add target for one-hot enconding

# %%
dataInterp['target'] = dataInterp['label'].map({'healthy':0, 'uncertain':1, 'stress':2, 'recovery':3})
dataInterp.target.astype('category')
dataInterp.head()

sorted_labels = ['healthy', 'uncertain', 'stress', 'recover']

# %% [markdown]
# ### Smoothing data on with a rolling mean (size=smoothWindow)

# %%
smoothWindow = 4

data = dataInterp.set_index(['Exp', 'Plant']).sort_index()
data['idx']=pd.NA
for t, gdf in data.groupby(['Exp', 'Plant']):
    data.loc[t, 'idx'] = np.arange(gdf.shape[0])
data.reset_index(inplace=True)
data.set_index(['Exp', 'Plant', 'idx'], inplace=True)
data.sort_index()

for c in ('Rds', 'DIgs', 'tds', 'tgs'):
    for t, gds in data.groupby(['Exp', 'Plant']):
        s = gds[c].rolling(smoothWindow).mean()
        data.loc[t,f"s{c}"] = s

for t, gds in data.groupby(['Exp', 'Plant']):
        s = gds['target'].rolling(smoothWindow).max().to_numpy()
        data.loc[t,'starget'] = s

# %% [markdown]
# ### Plot individual plant/parameter

# %%
exp = 'IMEM'
plant = 'B'
target = 'Rds'
starget = f"s{target}"

plt.figure(figsize=(12,5))
y = data.loc[exp,plant,:][target]
x = np.linspace(0,1,len(y))
plt.plot(x, y,'*', label='data')
ys = data.loc[exp, plant, :][starget]
x = np.linspace(0,1,len(ys))
plt.plot(x, ys, label='smoothed')
plt.title(target);
plt.legend();

# %%
sample = 4
shift = 0
targetCols = ['Rds', 'DIgs', 'tds', 'tgs', 'target', 'sRds', 'sDIgs', 'stds', 'stgs', 'starget']

dhour = pd.DataFrame()

for t, gdf in data.groupby(['Exp','Plant']):
    dhour = dhour.append(gdf[targetCols][shift::sample])

dhour.loc['ALSIA','A'].head()
# Out:
#           Rds      DIgs         tds        tgs  target      sRds     sDIgs  \
# idx
# 0    0.045589  0.000001   62.277342  16.037781       0       NaN       NaN
# 4    0.043619  0.000001   67.362482  14.888491       0  0.044208  0.000001
# 8    0.044490  0.000001   76.750356  14.420517       0  0.044191  0.000001
# 12   0.043707  0.000001   98.417203  14.297027       0  0.044287  0.000001
# 16   0.038998  0.000001  137.620720  14.415883       0  0.040452  0.000001
#
#            stds       stgs  starget
# idx
# 0           NaN        NaN      NaN
# 4     65.537782  15.320717      0.0
# 8     73.892083  14.504285      0.0
# 12    86.202022  14.347170      0.0
# 16   127.532720  14.403899      0.0

# %%
dhour.dropna(inplace=True)

dhour
# Out:
#                        Rds          DIgs         tds        tgs  target  \
# Exp   Plant idx
# ALSIA A     4     0.043619  1.040000e-06   67.362482  14.888491       0
#             8     0.044490  1.100000e-06   76.750356  14.420517       0
#             12    0.043707  1.110000e-06   98.417203  14.297027       0
#             16    0.038998  1.120000e-06  137.620720  14.415883       0
#             20    0.038100  1.150000e-06  118.467600  14.400891       0
# ...                    ...           ...         ...        ...     ...
# IMEM  G     1220  0.198553  1.530000e-06   54.551623  26.541186       1
#             1224  0.205493  1.480000e-06   52.629808  25.638631       1
#             1228  0.209944  1.460000e-06   51.233936  24.950834       1
#             1232  0.140186  9.790000e-07   50.360868  24.733251       1
#             1236  0.046414  3.310000e-07   48.906925  24.551891       1
#
#                       sRds         sDIgs        stds       stgs  starget
# Exp   Plant idx
# ALSIA A     4     0.044208  1.027500e-06   65.537782  15.320717      0.0
#             8     0.044191  1.080000e-06   73.892083  14.504285      0.0
#             12    0.044287  1.097500e-06   86.202022  14.347170      0.0
#             16    0.040452  1.112500e-06  127.532720  14.403899      0.0
#             20    0.038784  1.145000e-06  128.201122  14.393821      0.0
# ...                    ...           ...         ...        ...      ...
# IMEM  G     1220  0.196436  1.550000e-06   54.847223  26.673261      1.0
#             1224  0.202590  1.497500e-06   53.362164  26.005378      1.0
#             1228  0.208727  1.465000e-06   51.681850  25.150334      1.0
#             1232  0.175097  1.222250e-06   50.757825  24.804598      1.0
#             1236  0.081606  5.745000e-07   49.407965  24.616327      1.0
#
# [4095 rows x 10 columns]

# %% [markdown]
# ### Getting a dataframe with selected lagged measures

# %%
nlag = 9
target = ['Rds', 'DIgs', 'tds', 'tgs', 'target']

# %%
data_lagged = getLags(dhour, target, nlag)

# %%
data_lagged.columns
# Out:
# Index(['Rds_8', 'Rds_7', 'Rds_6', 'Rds_5', 'Rds_4', 'Rds_3', 'Rds_2', 'Rds_1',
#        'Rds_0', 'DIgs_8', 'DIgs_7', 'DIgs_6', 'DIgs_5', 'DIgs_4', 'DIgs_3',
#        'DIgs_2', 'DIgs_1', 'DIgs_0', 'tds_8', 'tds_7', 'tds_6', 'tds_5',
#        'tds_4', 'tds_3', 'tds_2', 'tds_1', 'tds_0', 'tgs_8', 'tgs_7', 'tgs_6',
#        'tgs_5', 'tgs_4', 'tgs_3', 'tgs_2', 'tgs_1', 'tgs_0', 'target_8',
#        'target_7', 'target_6', 'target_5', 'target_4', 'target_3', 'target_2',
#        'target_1', 'target_0', 'target'],
#       dtype='object')

# %% [markdown]
# ### Select interesting lags

# %%
ok_cols = []

for c in ['Rds', 'DIgs', 'tds', 'tgs']:
    for lag in range(0, nlag, 3):
        ok_cols.append(f"{c}_{lag}")

ok_cols.append('target_0')
        
data_lagged = data_lagged[ok_cols]
data_lagged.rename(columns={'target_0':'target'}, inplace=True)

data_lagged
# Out:
#                      Rds_0     Rds_3     Rds_6        DIgs_0    DIgs_3  \
# Exp   Plant idx
# ALSIA A     40    0.039871  0.039349  0.043707  1.460000e-06  0.000001
#             44    0.035122  0.041151  0.038998  1.390000e-06  0.000001
#             48    0.034494  0.042195  0.038100  1.340000e-06  0.000001
#             52    0.034720  0.039871  0.039349  1.410000e-06  0.000001
#             56    0.033246  0.035122  0.041151  1.310000e-06  0.000001
# 56    48.548384  43.307764  43.617871  21.527810   24.164990   24.806150
# ...         ...        ...        ...        ...         ...         ...
# 1220  96.056057  29.472369  48.698790  60.858744   72.216893   45.555293
# 1224  82.207559  40.416881  45.785364  38.340947  110.261460   43.854828
# 1228  60.318829  63.445211  37.748577  42.355587  102.659710   20.785257
# 1232  42.753496  96.056057  29.472369  45.158544   60.858744   72.216893
# 1236  41.654676  82.207559  40.416881  35.951324   38.340947  110.261460
#
#       target
# idx
# 40       0.0
# 44       0.0
# 48       0.0
# 52       0.0
# 56       0.0
# ...      ...
# 1220     0.0
# 1224     0.0
# 1228     0.0
# 1232     0.0
# 1236     0.0
#
# [300 rows x 13 columns]

# %%
exp = 'IMEM'
plantId = 'D'


# map({'healthy':0, 'uncertain':1, 'stress':2, 'recovery':3})
df = data_lagged.loc[exp,plantId].reset_index()
df['time'] = np.arange(0,len(df)/4, .25)  
labels = { 0:'green', 1:'gray', 2:'red', 3:'blue'}

target='Rds_0'

# print( df['target'].unique())


for l in df['target'].unique():
    df_tmp = df[df.target==l]
    x = np.diff(df_tmp.index.values)
#     print(x)
#     print(df_tmp)
    splits=np.where(x>1)[0] + 1 # accounts for diff lag
    

    if df_tmp.index.values[-1] < df.index.values[-1]:
        df_tmp = df_tmp.append(df.iloc[df_tmp.index.values[-1]+1])
    
    if len(splits)>0:
        prevIdx = 0
        for idx in splits:
            plt.plot(df_tmp['time'][prevIdx:idx], df_tmp['Rds_0'][prevIdx:idx], c=labels[int(l)])
            prevIdx = idx

        plt.plot(df_tmp['time'][idx:], df_tmp['Rds_0'][idx:], c=labels[l], label=l)

    else:
        idx = df_tmp.index[0]-1
        if idx < 0:
            idx = 0
        toIdx = df_tmp.index[-1]    
        plt.plot(df['time'][idx:toIdx], df['Rds_0'][idx:toIdx], c=labels[l], label=l)

        
# print(len(df_tmp), max(df_tmp.index.values), df.iloc[221]['Rds_0'])
# df_tmp.append(df.iloc[2])

# max(df.index.values), df.index.values[-1]
# df

# %%
def plotLaggedPlant(data, exp, plantId, t, tmin=0, tmax=None, figSize=(5,3.5), figFileName=None):

    df = data.loc[exp,plantId].reset_index()
#  convert time from sample id (15') to hour
    df['time'] = np.arange(0,len(df)/4, .25)  
    
    if tmax==None:
        tmax = 1.2 * t
    
    
    df = df[df.time >= tmin]
    df = df[df.time <= tmax] 
    
    df.set_index('time', inplace=True)
    
    df['Rds_0'] = df['Rds_0']*1000.0

    matplotlib.rc_file_defaults()

    fig, ax = plt.subplots(figsize=figSize)
        
    ax.plot(df['Rds_0'], linewidth=1)
    
    for lag in (0,3,6):
        if lag==0:
            ax.scatter(t-lag, df.loc[t-lag]['Rds_0'], marker='x', c='red')
            ax.axvline(t-lag, ls='--', color = 'black', )
        else:
            ax.scatter(t-lag, df.loc[t-lag]['Rds_0'], marker='x', c='black')
            ax.axvline(t-lag, ls=':', color = 'gray', )

    ax.annotate(f"t={t}", xy =[t+1, min(df['Rds_0'])])
    
    ax.set_xlabel('Time [hour]')
    ax.set_ylabel('Rds [$m\Omega$]')
    ax.set_xticks([tmin, t-6,t-3, t, int(tmax)])
    ax.set_xticklabels( (tmin, 't-6', 't-3', 't', int(tmax))  )
    
#     ymin = min(df['Rds_0'])
#     ymax = max(df['Rds_0'])
    
#     ytics = np.arange(ymin,ymax, (ymax-ymin)/4).tolist()
#     ytics.append(ymax)
    
#     ytics = [115, 145, 175]
#     ax.set_yticks(ytics)
    
    if figFileName != None:
        fig.savefig(figFileName)
    

    
def plotSmoothedata(data, exp, plantId, t, tahead, figSize=(12,10), figFileName=None, tzoom=None ):
    df = data.loc[exp,plantId].reset_index()
#  convert time from sample id (15') to hour
    df['time'] = np.arange(0,len(df)/4, .25)  
#     df.set_index('time', inplace=True)

    if tzoom != None:
        df = df[df.time >= tzoom[0]]
        df = df[df.time <= tzoom[1]]

    matplotlib.rc_file_defaults()
    fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2,2, figsize=figSize)
    
    ax1.plot(df['time'], df['Rds_0'])
    ax1.set_xlabel('Time [hour]')
    ax1.set_ylabel('Rds [$\Omega$]')

    ax1.axvline(t, ls=':', color = 'black', )
    ax1.axvline(t-3, ls=':', color = 'gray')
    ax1.axvline(t-6, ls=':', color = 'gray')
    
    ax2.plot(df['time'], df['DIgs_0'])
    ax2.set_xlabel('Time [hour]')
    ax2.set_ylabel('DIgs [$\mu A$]')

    ax2.axvline(t, ls=':', color = 'black', )
    
    ax2.axvline(t-3, ls=':', color = 'gray')
    ax2.axvline(t-6, ls=':', color = 'gray')
    
    ax3.plot(df['time'], df['tds_0'])
    ax3.set_xlabel('Time [hour]')
    ax3.set_ylabel('tds [s]')

    ax3.axvline(t, ls=':', color = 'black', )
#     ax3.axvline(t+tahead, ls=':', color = 'red' )
    ax3.axvline(t-3, ls=':', color = 'gray')
    ax3.axvline(t-6, ls=':', color = 'gray')

    ax4.plot(df['time'], df['tgs_0'])
    ax4.set_xlabel('Time [hour]')
    ax4.set_ylabel('tgs [s]')

    ax4.axvline(t, ls=':', color = 'black', )
    ax4.axvline(t-3, ls=':', color = 'gray')
    ax4.axvline(t-6, ls=':', color = 'gray')
#     ax4.axvline(t+tahead, ls=':', color = 'red' )
    
    
    if figFileName != None:
        fig.savefig(figFileName)

# %%
exp='IMEM'
plantId='D'

# data_lagged.columns

# plotPlant(rawdata, exp, plantId, 'DIgs', dataInterp=dataInterp, figSize=(15,5))
    
# plotSmoothedata(data_lagged, exp, plantId, t=22, tahead=12, figFileName='rds-lagged.png', tzoom=(0, 48))
plotLaggedPlant(data_lagged, exp, plantId, t=18, tmin=0, tmax=24, figFileName='rds-lagged.png')

# %% [markdown]
# # Neural Network models

# %%
n=len(data_lagged)
n, n*.8, n*.2, n*.8*12
# Out:
# (3978, 3182.4, 795.6, 38188.8)

# %%
nepochs = 300
patience = 10

# %% [markdown]
# ## RNN 4 states

# %%
nsteps = 1
test_th = 0.2

X, Y, Y2 = getTensors(data_lagged, 'target', nsteps)

(x_train, x_test, y_train, y_test) = train_test_split(X, Y, test_size=test_th, shuffle=True)

sc = StandardScaler()
sc.fit(x_train)

x_train = sc.transform(x_train)
x_test = sc.transform(x_test)

# %%
nLSTMs = 20

# model = tf.keras.Sequential()
# model.add(layers.LSTM(nLSTMs, activation='relu', input_shape=(X.shape[1], 1)))
# model.add(layers.Dense(Y.shape[1], activation='softmax'))
# model.compile(optimizer=tf.keras.optimizers.Adam(), loss='categorical_crossentropy',  metrics =['accuracy', 'categorical_accuracy',
#                               tf.keras.metrics.Precision(),
#                               tf.keras.metrics.Recall() ])

model = tf.keras.Sequential()
model.add(layers.LSTM(nLSTMs, activation='relu', input_shape=(X.shape[1], 1)))
# model.add(layers.Dense(8, activation='relu'))
model.add(layers.Dense(Y.shape[1], activation='softmax'))
model.compile(optimizer=tf.keras.optimizers.Adam(), loss='categorical_crossentropy',  metrics =['accuracy', 'categorical_accuracy',
                              tf.keras.metrics.Precision(),
                              tf.keras.metrics.Recall() ])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 20)                1760
#
#  dense (Dense)               (None, 4)                 84
#
# =================================================================
# Total params: 1,844
# Trainable params: 1,844
# Non-trainable params: 0
# _________________________________________________________________

# %%
from  tensorflow.keras.utils import plot_model
plot_model(model, show_shapes=True, show_layer_names=True)

# %%
y_integers = np.argmax(Y, axis=1)
weights = compute_class_weight('balanced', classes=np.unique(y_integers), y=y_integers)
print('balanced class weights:', weights*2)
weights= {0:1,1:1,2:4,3:1}
print('actual class weights:',weights)
# Out:
# balanced class weights: [0.92553688 2.69727891 2.80807365 5.18979058]
# actual class weights: {0: 1, 1: 1, 2: 4, 3: 1}

# %%
callback = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=patience)

# model.fit(x_train, y_train, class_weight=weights, epochs=nepochs, batch_size=100, verbose=1)
# model.fit(x_train, y_train, class_weight=weights, epochs=nepochs,  verbose=1)
model_hist = model.fit(x_train, y_train, class_weight=weights, epochs=nepochs, verbose=1, callbacks=[callback])
# Out:
# Epoch 1/300
# 100/100 [==============================] - 2s 7ms/step - loss: 1.8831 - accuracy: 0.3178 - categorical_accuracy: 0.3178 - precision: 0.3855 - recall: 0.0435
# Epoch 2/300
# 100/100 [==============================] - 1s 6ms/step - loss: 1.5408 - accuracy: 0.5832 - categorical_accuracy: 0.5832 - precision: 0.6065 - recall: 0.3897
# Epoch 3/300
# 100/100 [==============================] - 1s 6ms/step - loss: 1.4823 - accuracy: 0.5820 - categorical_accuracy: 0.5820 - precision: 0.6174 - recall: 0.4278
# Epoch 4/300
# 100/100 [==============================] - 1s 6ms/step - loss: 1.4576 - accuracy: 0.5829 - categorical_accuracy: 0.5829 - precision: 0.6302 - recall: 0.4265
# Epoch 5/300
# 100/100 [==============================] - 1s 6ms/step - loss: 1.4272 - accuracy: 0.5962 - categorical_accuracy: 0.5962 - precision: 0.6303 - recall: 0.4369
# Epoch 6/300
# 100/100 [==============================] - 1s 6ms/step - loss: 1.4177 - accuracy: 0.5772 - categorical_accuracy: 0.5772 - precision: 0.6346 - recall: 0.3931
# Epoch 7/300
# 100/100 [==============================] - 1s 6ms/step - loss: 1.3911 - accuracy: 0.5798 - categorical_accuracy: 0.5798 - precision: 0.6169 - recall: 0.4158
# Epoch 8/300
# 100/100 [==============================] - 1s 6ms/step - loss: 1.3489 - accuracy: 0.5908 - categorical_accuracy: 0.5908 - precision: 0.6402 - recall: 0.4369
# Epoch 9/300
# 100/100 [==============================] - 1s 6ms/step - loss: 1.3076 - accuracy: 0.5933 - categorical_accuracy: 0.5933 - precision: 0.6439 - recall: 0.4647
# Epoch 10/300
# 100/100 [==============================] - 1s 6ms/step - loss: 1.2474 - accuracy: 0.5987 - categorical_accuracy: 0.5987 - precision: 0.6561 - recall: 0.4823
# Epoch 11/300
# 100/100 [==============================] - 1s 6ms/step - loss: 1.1736 - accuracy: 0.6248 - categorical_accuracy: 0.6248 - precision: 0.6781 - recall: 0.5359
# Epoch 12/300
# 100/100 [==============================] - 1s 6ms/step - loss: 1.1309 - accuracy: 0.6286 - categorical_accuracy: 0.6286 - precision: 0.6973 - recall: 0.5643
# Epoch 13/300
# 100/100 [==============================] - 1s 6ms/step - loss: 1
300
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2214 - accuracy: 0.9253 - categorical_accuracy: 0.9253 - precision: 0.9281 - recall: 0.9234
# Epoch 192/300
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2595 - accuracy: 0.9117 - categorical_accuracy: 0.9117 - precision: 0.9158 - recall: 0.9089
# Epoch 193/300
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2538 - accuracy: 0.9202 - categorical_accuracy: 0.9202 - precision: 0.9242 - recall: 0.9180
# Epoch 194/300
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2588 - accuracy: 0.9139 - categorical_accuracy: 0.9139 - precision: 0.9180 - recall: 0.9111

# %%
model.save('RNN-4states.model')
# Out:
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: RNN-4states.model/assets
# INFO:tensorflow:Assets written to: RNN-4states.model/assets

# %%
yp = model.predict(x_test)
yp_class = np.round(yp)

sorted_labels = ['healty', 'uncertain','stress','recover']

score = model.evaluate(x_test, y_test, verbose=0)

print(f"Accuracy:  {score[1]*100:.2f}%")
print(f"Accuracy2: {score[2]*100:.2f}%")
print(f"Precision: {score[3]*100:.2f}%")
print(f"Recall:    {score[4]*100:.2f}%")

# print(confusion_matrix(np.argmax(y_test, axis=1), np.argmax(yp_class, axis=1)))

cmatrix = confusion_matrix(np.argmax(y_test, axis=1), np.argmax(yp_class, axis=1))
# Out:
# 25/25 [==============================] - 0s 2ms/step
# Accuracy:  88.52%
# Accuracy2: 88.52%
# Precision: 89.03%
# Recall:    88.02%

# %%
plt.figure(figsize=(12.8, 6))
sns.set(font_scale=1.8)
sns.heatmap(cmatrix, annot=True, xticklabels=sorted_labels, yticklabels=sorted_labels, annot_kws={"size": 20}, cmap="Blues", fmt="g")
plt.xlabel('Predicted', fontsize = 25, weight='bold');
plt.ylabel('Actual', fontsize = 25, weight='bold');
plt.title(f'Forecast: {nsteps} hour ahead');
# sns.heatmap(cmatrix, annot=True, fmt='d', annot_kws={"fontsize": 16}, cbar=False, xticklabels=sorted_labels, yticklabels=sorted_labels,cmap='Blues');

# %% [markdown]
# ## RNN binary modeling

# %%
classificator = tf.keras.Sequential()
classificator.add(layers.LSTM(nLSTMs, activation='relu', input_shape=(X.shape[1], 1)))
# classificator.add(layers.Dense(2, activation='relu'))
classificator.add(layers.Dense(1, activation='sigmoid'))
classificator.compile(optimizer=tf.keras.optimizers.Adam(), loss='binary_crossentropy', metrics =['accuracy',
                              tf.keras.metrics.Precision(),
                              tf.keras.metrics.Recall() ])

classificator.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_1 (LSTM)               (None, 20)                1760
#
#  dense_1 (Dense)             (None, 1)                 21
#
# =================================================================
# Total params: 1,781
# Trainable params: 1,781
# Non-trainable params: 0
# _________________________________________________________________

# %%
plot_model(classificator, show_shapes=True, show_layer_names=True)

# %%
(x_train, x_test, y_train, y_test) = train_test_split(X, Y2, test_size=test_th, shuffle=True)

sc = StandardScaler()
sc.fit(x_train)

x_train = sc.transform(x_train)
x_test = sc.transform(x_test)

# %%
pd.DataFrame(y_train).value_counts()
# Out:
# 0.0    2599
# 1.0     573
# dtype: int64

# %%
weights={0:1, 1:4}
# weights = {0:1, 1:1}

# %%
class_hist = classificator.fit(x_train, y_train.reshape(-1,1), class_weight=weights, epochs=nepochs, verbose=1, callbacks=[ callback ])
# classificator.save('RNN-binary')
# Out:
# Epoch 1/300
# 100/100 [==============================] - 2s 6ms/step - loss: 1.0079 - accuracy: 0.6885 - precision_1: 0.3084 - recall_1: 0.5829
# Epoch 2/300
# 100/100 [==============================] - 1s 5ms/step - loss: 0.8686 - accuracy: 0.8090 - precision_1: 0.4718 - recall_1: 0.4817
# Epoch 3/300
# 100/100 [==============================] - 1s 5ms/step - loss: 0.8208 - accuracy: 0.7894 - precision_1: 0.4350 - recall_1: 0.5550
# Epoch 4/300
# 100/100 [==============================] - 1s 5ms/step - loss: 0.8048 - accuracy: 0.7812 - precision_1: 0.4221 - recall_1: 0.5724
# Epoch 5/300
# 100/100 [==============================] - 1s 6ms/step - loss: 0.7899 - accuracy: 0.7705 - precision_1: 0.4100 - recall_1: 0.6161
# Epoch 6/300
# 100/100 [==============================] - 1s 6ms/step - loss: 0.7725 - accuracy: 0.7569 - precision_1: 0.3971 - recall_1: 0.6667
# Epoch 7/300
# 100/100 [==============================] - 1s 6ms/step - loss: 0.7703 - accuracy: 0.7491 - precision_1: 0.3910 - recall_1: 0.6981
# Epoch 8/300
# 100/100 [==============================] - 1s 6ms/step - loss: 0.7515 - accuracy: 0.7352 - precision_1: 0.3763 - recall_1: 0.7086
# Epoch 9/300
# 100/100 [==============================] - 1s 6ms/step - loss: 0.7349 - accuracy: 0.7327 - precision_1: 0.3773 - recall_1: 0.7382
# Epoch 10/300
# 100/100 [==============================] - 1s 6ms/step - loss: 0.7258 - accuracy: 0.7298 - precision_1: 0.3790 - recall_1: 0.7766
# Epoch 11/300
# 100/100 [==============================] - 1s 6ms/step - loss: 0.7188 - accuracy: 0.7219 - precision_1: 0.3761 - recall_1: 0.8185
# Epoch 12/300
# 100/100 [==============================] - 1s 6ms/step - loss: 0.6977 - accuracy: 0.7481 - precision_1: 0.4014 - recall_1: 0.8028
# Epoch 13/300
# 100/100 [==============================] - 1s 6ms/step - loss: 0.6727 - accuracy: 0.7513 - precision_1: 0.4077 - recall_1: 0.8325
# Epoch 14/300
# 100/100 [==============================] - 1s 6ms/step - loss: 0.6486 - accuracy: 0.7689 - precision_1: 0.4284 - recall_1: 0.8360
# Epoch 15/300
# 100/100 [==============================] - 1s 6ms/step - loss: 0.6305 - accuracy: 0.7869 - precision_1: 0.4517 - recall_1: 0.8412
# Epoch 16/300
# 100/100 [==============================] - 1s 6ms/step - loss: 0.6058 - accuracy: 0.8124 - precision_1: 0.4889 - recall_1: 0.8429
# Epoch 17/300
# 100/100 [==============================] - 1s 6ms/step - loss: 0.6005 - accuracy: 0.8102 - precision_1: 0.4856 - recall_1: 0.8534
# Epoch 18/300
# 100/100 [==============================] - 1s 6ms/step - loss: 0.5565 - accuracy: 0.8282 - precision_1: 0.5147 - recall_1: 0.8534
# Epoch 19/300
# 100/100 [==============================] - 1s 6ms/step - loss: 0.5343 - accuracy: 0.8272 - precision_1: 0.5130 - recall_1: 0.8639
# Epoch 20/300
# 100/100 [==============================] - 1s 6ms/step - loss: 0.5161 - accuracy: 0.8317 - precision_1: 0.5201 - recall_1: 0.8813
# Epoch 21/300
# 100/100 [==============================] - 1s 6ms/step - loss: 0.5194 - accuracy: 0.8414 - precision_1: 0.5373 - recall_1: 0.8796
# Epoch 22/300
# 100/100 [==============================] - 1s 6ms/step - loss: 0.4808 - accuracy: 0.8480 - precision_1: 0.5478 - recall_1: 0.9092
# Epoch 23/300
# 100/100 [==============================] - 1s 6ms/step - loss: 0.4674 - accuracy: 0.8537 - precision_1: 0.5592 - recall_1: 0.8988
# Epoch 24/300
# 100/100 [==============================] - 1s 6ms/step - loss: 0.4538 - accuracy: 0.8632 - precision_1: 0.5780 - recall_1: 0.8988
# Epoch 25/300
# 100/100 [==============================] - 1s 6ms/step - loss: 0.4402 - accuracy: 0.8600 - precision_1: 0.5708 - recall_1: 0.9075
# Epoch 26/300
# 100/100 [==============================] - 1s 6ms/step - loss: 0.4273 - accuracy: 0.8695 - precision_1: 0.5894 - recall_1: 0.9145
# Epoch 27/300
# 100/100 [==============================] - 1s 6ms/step - loss: 0.4196 - accuracy: 0.8704 - precision_1: 0.5931 - recall_1: 0.9005
# Epoch 28/300
# 100/100 [==============================] - 1s 7ms/step - loss: 0.4170 - accuracy: 0.8720 - precision_1: 0.5952 - recall_1: 0.9110
# Epoch 29/300
# 100/100 [==============================] - 1s 7ms/step - loss: 0.3972 - accuracy: 0.8780 - precision_1: 0.6069 - recall_1: 0.9215
# Epoch 30/300
# 100/100 [==============================] - 1s 6ms/step - loss: 0.3695 - accuracy: 0.8852 - precision_1: 0.6234 - recall_1: 0.9215
# Epoch 31/300
# 100/100 [==============================] - 1s 6ms/step - loss: 0.3800 - accuracy: 0.8846 - precision_1: 0.6237 - recall_1: 0.9110
# Epoch 32/300
# 100/100 [==============================] - 1s 6ms/step - loss: 0.3676 - accuracy: 0.8856 - precision_1: 0.6221 - recall_1: 0.9337
# Epoch 33/300
# 100/100 [==============================] - 1s 6ms/step - loss: 0.3663 - accuracy: 0.8903 - precision_1: 0.6347 - recall_1: 0.9250
# Epoch 34/300
# 100/100 [==============================] - 1s 6ms/step - loss: 0.3566 - accuracy: 0.8950 - precision_1: 0.6442 - recall_1: 0.9354
# Epoch 35/300
# 100/100 [==============================] - 1s 6ms/step - loss: 0.3744 - accuracy: 0.8849 - precision_1: 0.6212 - recall_1: 0.9302
# Epoch 36/300
# 100/100 [==============================] - 1s 6ms/step - loss: 0.3281 - accuracy: 0.8991 - precision_1: 0.6522 - recall_1: 0.9459
# Epoch 37/300
# 100/100 [==============================] - 1s 6ms/step - loss: 0.3364 - accuracy: 0.9004 - precision_1: 0.6558 - recall_1: 0.9442
# Epoch 38/300
# 100/100 [==============================] - 1s 6ms/step - loss: 0.3275 - accuracy: 0.8953 - precision_1: 0.6406 - recall_1: 0.9581
# Epoch 39/300
# 100/100 [==============================] - 1s 6ms/step - loss: 0.3287 - accuracy: 0.8985 - precision_1: 0.6514 - recall_1: 0.9424
# Epoch 40/300
# 100/100 [==============================] - 1s 6ms/step - loss: 0.3366 - accuracy: 0.8928 - precision_1: 0.6392 - recall_1: 0.9337
# Epoch 41/300
# 100/100 [==============================] - 1s 6ms/step - loss: 0.3260 - accuracy: 0.9020 - precision_1: 0.6590 - recall_1: 0.9476
# Epoch 42/300
# 100/100 [==============================] - 1s 6ms/step - loss: 0.3891 - accuracy: 0.8944 - precision_1: 0.6437 - recall_1: 0.9302
# Epoch 43/300
# 100/100 [==============================] - 1s 6ms/step - loss: 0.6328 - accuracy: 0.7885 - precision_1: 0.4550 - recall_1: 0.8656
# Epoch 44/300
# 100/100 [==============================] - 1s 6ms/step - loss: 0.5103 - accuracy: 0.8515 - precision_1: 0.5536 - recall_1: 0.9197
# Epoch 45/300
# 100/100 [==============================] - 1s 6ms/step - loss: 0.4481 - accuracy: 0.8726 - precision_1: 0.5934 - recall_1: 0.9372
# Epoch 46/300
# 100/100 [==============================] - 1s 6ms/step - loss: 0.4013 - accuracy: 0.8789 - precision_1: 0.6051 - recall_1: 0.9494
# Epoch 47/300
# 100/100 [==============================] - 1s 6ms/step - loss: 0.3695 - accuracy: 0.8827 - precision_1: 0.6143 - recall_1: 0.9424
# Epoch 48/300
# 100/100 [==============================] - 1s 6ms/step - loss: 0.3328 - accuracy: 0.8997 - precision_1: 0.6523 - recall_1: 0.9529
# Epoch 49/300
# 100/100 [==============================] - 1s 6ms/step - loss: 0.3305 - accuracy: 0.8972 - precision_1: 0.6465 - recall_1: 0.9511
# Epoch 50/300
# 100/100 [==============================] - 1s 6ms/step - loss: 0.3125 - accuracy: 0.9054 - precision_1: 0.6679 - recall_1: 0.9476
# Epoch 51/300
# 100/100 [==============================] - 1s 6ms/step - loss: 0.3129 - accuracy: 0.9048 - precision_1: 0.6642 - recall_1: 0.9564
# Epoch 52/300
# 100/100 [==============================] - 1s 6ms/step - loss: 0.3060 - accuracy: 0.9045 - precision_1: 0.6630 - recall_1: 0.9581
# Epoch 53/300
# 100/100 [==============================] - 1s 6ms/step - loss: 0.3137 - accuracy: 0.9016 - precision_1: 0.6582 - recall_1: 0.9476
# Epoch 54/300
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2953 - accuracy: 0.9032 - precision_1: 0.6618 - recall_1: 0.9494
# Epoch 55/300
# 100/100 [==============================] - 1s 6ms/step - loss: 0.3059 - accuracy: 0.9035 - precision_1: 0.6614 - recall_1: 0.9546
# Epoch 56/300
# 100/100 [==============================] - 1s 6ms/step - loss: 0.3047 - accuracy: 0.9029 - precision_1: 0.6602 - recall_1: 0.9529
# Epoch 57/300
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2966 - accuracy: 0.9054 - precision_1: 0.6675 - recall_1: 0.9494
# Epoch 58/300
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2929 - accuracy: 0.9061 - precision_1: 0.6675 - recall_1: 0.9564
# Epoch 59/300
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2954 - accuracy: 0.9105 - precision_1: 0.6786 - recall_1: 0.9581
# Epoch 60/300
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2811 - accuracy: 0.9111 - precision_1: 0.6812 - recall_1: 0.9546
# Epoch 61/300
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2803 - accuracy: 0.9142 - precision_1: 0.6893 - recall_1: 0.9564
# Epoch 62/300
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2935 - accuracy: 0.9010 - precision_1: 0.6544 - recall_1: 0.9581
# Epoch 63/300
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2801 - accuracy: 0.9111 - precision_1: 0.6807 - recall_1: 0.9564
# Epoch 64/300
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2898 - accuracy: 0.9070 - precision_1: 0.6703 - recall_1: 0.9546
# Epoch 65/300
# 100/100 [==============================] - 1s 7ms/step - loss: 0.2733 - accuracy: 0.9127 - precision_1: 0.6845 - recall_1: 0.9581
# Epoch 66/300
# 100/100 [==============================] - 1s 7ms/step - loss: 0.2792 - accuracy: 0.9127 - precision_1: 0.6836 - recall_1: 0.9616
# Epoch 67/300
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2751 - accuracy: 0.9114 - precision_1: 0.6811 - recall_1: 0.9581
# Epoch 68/300
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2808 - accuracy: 0.9165 - precision_1: 0.6949 - recall_1: 0.9581
# Epoch 69/300
# 100/100 [==============================] - 1s 6ms/step - loss: 0.3069 - accuracy: 0.9038 - precision_1: 0.6614 - recall_1: 0.9581
# Epoch 70/300
# 100/100 [==============================] - 1s 5ms/step - loss: 0.2775 - accuracy: 0.9127 - precision_1: 0.6832 - recall_1: 0.9634
# Epoch 71/300
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2957 - accuracy: 0.8975 - precision_1: 0.6445 - recall_1: 0.9651
# Epoch 72/300
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2745 - accuracy: 0.9136 - precision_1: 0.6866 - recall_1: 0.9599
# Epoch 73/300
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2740 - accuracy: 0.9136 - precision_1: 0.6853 - recall_1: 0.9651
# Epoch 74/300
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2690 - accuracy: 0.9133 - precision_1: 0.6877 - recall_1: 0.9529
# Epoch 75/300
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2653 - accuracy: 0.9158 - precision_1: 0.6922 - recall_1: 0.9616
# Epoch 76/300
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2863 - accuracy: 0.9042 - precision_1: 0.6638 - recall_1: 0.9511
# Epoch 77/300
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2687 - accuracy: 0.9177 - precision_1: 0.7000 - recall_1: 0.9529
# Epoch 78/300
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2863 - accuracy: 0.9102 - precision_1: 0.6760 - recall_1: 0.9651
# Epoch 79/300
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2740 - accuracy: 0.9114 - precision_1: 0.6811 - recall_1: 0.9581
# Epoch 80/300
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2571 - accuracy: 0.9209 - precision_1: 0.7069 - recall_1: 0.9599
# Epoch 81/300
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2894 - accuracy: 0.9079 - precision_1: 0.6754 - recall_1: 0.9442
# Epoch 82/300
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2645 - accuracy: 0.9180 - precision_1: 0.6989 - recall_1: 0.9599
# Epoch 83/300
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2536 - accuracy: 0.9221 - precision_1: 0.7053 - recall_1: 0.9773
# Epoch 84/300
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2585 - accuracy: 0.9199 - precision_1: 0.7027 - recall_1: 0.9651
# Epoch 85/300
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2795 - accuracy: 0.9124 - precision_1: 0.6814 - recall_1: 0.9668
# Epoch 86/300
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2794 - accuracy: 0.9114 - precision_1: 0.6789 - recall_1: 0.9668
# Epoch 87/300
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2626 - accuracy: 0.9146 - precision_1: 0.6888 - recall_1: 0.9616
# Epoch 88/300
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2643 - accuracy: 0.9209 - precision_1: 0.7043 - recall_1: 0.9686
# Epoch 89/300
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2740 - accuracy: 0.9206 - precision_1: 0.7082 - recall_1: 0.9529
# Epoch 90/300
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2527 - accuracy: 0.9168 - precision_1: 0.6934 - recall_1: 0.9668
# Epoch 91/300
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2401 - accuracy: 0.9272 - precision_1: 0.7215 - recall_1: 0.9721
# Epoch 92/300
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2490 - accuracy: 0.9193 - precision_1: 0.6989 - recall_1: 0.9721
# Epoch 93/300
# 100/100 [==============================] - 1s 5ms/step - loss: 0.2541 - accuracy: 0.9161 - precision_1: 0.6926 - recall_1: 0.9634
# Epoch 94/300
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2451 - accuracy: 0.9209 - precision_1: 0.7054 - recall_1: 0.9651
# Epoch 95/300
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2689 - accuracy: 0.9193 - precision_1: 0.7014 - recall_1: 0.9634
# Epoch 96/300
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2515 - accuracy: 0.9209 - precision_1: 0.7048 - recall_1: 0.9668
# Epoch 97/300
# 100/100 [==============================] - 1s 5ms/step - loss: 0.2498 - accuracy: 0.9259 - precision_1: 0.7183 - recall_1: 0.9703
# Epoch 98/300
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2367 - accuracy: 0.9256 - precision_1: 0.7185 - recall_1: 0.9668
# Epoch 99/300
# 100/100 [==============================] - 1s 5ms/step - loss: 0.2431 - accuracy: 0.9190 - precision_1: 0.6990 - recall_1: 0.9686
# Epoch 100/300
# 100/100 [==============================] - 1s 5ms/step - loss: 0.2348 - accuracy: 0.9256 - precision_1: 0.7180 - recall_1: 0.9686
# Epoch 101/300
# 100/100 [==============================] - 1s 5ms/step - loss: 0.2537 - accuracy: 0.9209 - precision_1: 0.7064 - recall_1: 0.9616
# Epoch 102/300
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2397 - accuracy: 0.9240 - precision_1: 0.7134 - recall_1: 0.9686
# Epoch 103/300
# 100/100 [==============================] - 1s 5ms/step - loss: 0.2469 - accuracy: 0.9262 - precision_1: 0.7187 - recall_1: 0.9721
# Epoch 104/300
# 100/100 [==============================] - 1s 5ms/step - loss: 0.3086 - accuracy: 0.9089 - precision_1: 0.6740 - recall_1: 0.9599
# Epoch 105/300
# 100/100 [==============================] - 1s 5ms/step - loss: 0.2550 - accuracy: 0.9193 - precision_1: 0.7009 - recall_1: 0.9651
# Epoch 106/300
# 100/100 [==============================] - 1s 5ms/step - loss: 0.2316 - accuracy: 0.9278 - precision_1: 0.7240 - recall_1: 0.9703
# Epoch 107/300
# 100/100 [==============================] - 1s 5ms/step - loss: 0.2236 - accuracy: 0.9303 - precision_1: 0.7298 - recall_1: 0.9756
# Epoch 108/300
# 100/100 [==============================] - 1s 5ms/step - loss: 0.2219 - accuracy: 0.9319 - precision_1: 0.7339 - recall_1: 0.9773
# Epoch 109/300
# 100/100 [==============================] - 1s 5ms/step - loss: 0.2296 - accuracy: 0.9322 - precision_1: 0.7374 - recall_1: 0.9703
# Epoch 110/300
# 100/100 [==============================] - 1s 5ms/step - loss: 0.2550 - accuracy: 0.9234 - precision_1: 0.7137 - recall_1: 0.9616
# Epoch 111/300
# 100/100 [==============================] - 1s 5ms/step - loss: 0.2184 - accuracy: 0.9300 - precision_1: 0.7288 - recall_1: 0.9756
# Epoch 112/300
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2263 - accuracy: 0.9338 - precision_1: 0.7391 - recall_1: 0.9791
# Epoch 113/300
# 100/100 [==============================] - 1s 5ms/step - loss: 0.2161 - accuracy: 0.9313 - precision_1: 0.7332 - recall_1: 0.9738
# Epoch 114/300
# 100/100 [==============================] - 1s 5ms/step - loss: 0.2255 - accuracy: 0.9316 - precision_1: 0.7336 - recall_1: 0.9756
# Epoch 115/300
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2188 - accuracy: 0.9332 - precision_1: 0.7410 - recall_1: 0.9686
# Epoch 116/300
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2324 - accuracy: 0.9237 - precision_1: 0.7130 - recall_1: 0.9668
# Epoch 117/300
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2417 - accuracy: 0.9281 - precision_1: 0.7273 - recall_1: 0.9634
# Epoch 118/300
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2432 - accuracy: 0.9253 - precision_1: 0.7165 - recall_1: 0.9703
# Epoch 119/300
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2253 - accuracy: 0.9297 - precision_1: 0.7291 - recall_1: 0.9721
# Epoch 120/300
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2208 - accuracy: 0.9319 - precision_1: 0.7358 - recall_1: 0.9721
# Epoch 121/300
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2279 - accuracy: 0.9300 - precision_1: 0.7276 - recall_1: 0.9791
# Epoch 122/300
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2375 - accuracy: 0.9306 - precision_1: 0.7356 - recall_1: 0.9616
# Epoch 123/300
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2252 - accuracy: 0.9306 - precision_1: 0.7301 - recall_1: 0.9773

# %%
model.save('RNN-2states.model')
# Out:
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: RNN-2states.model/assets
# INFO:tensorflow:Assets written to: RNN-2states.model/assets

# %%
yp = classificator.predict(x_test)
yp_predicted_class = np.round(yp)
score = classificator.evaluate(x_test, y_test, verbose=0)

score
# Out:
# 25/25 [==============================] - 0s 2ms/step
# [0.1625584065914154, 0.935687243938446, 0.7356321811676025, 0.9624060392379761]

# %%
print(f"Accuracy:  {score[1]*100:.2f}%")
print(f"Precision: {score[2]*100:.2f}%")
print(f"Recall:    {score[3]*100:.2f}%")

cmatrix = confusion_matrix(y_test, yp_predicted_class)

sns.heatmap(cmatrix, annot=True, xticklabels=binlabels, yticklabels=binlabels, annot_kws={"size": 20}, cmap="Blues", fmt="g")
plt.xlabel('Predicted', fontsize = 25, weight='bold');
plt.ylabel('Actual', fontsize = 25, weight='bold');
plt.title(f'Forecast: {nsteps} hour ahead');
# Out:
# Accuracy:  93.57%
# Precision: 73.56%
# Recall:    96.24%

# %% [markdown]
# # Varying the number of ahead prediction lag

# %%
nsteps=24
nLSTMs = 30

X, Y, Y2 = getTensors(data_lagged, 'target', nsteps)

(x_train, x_test, y_train, y_test) = train_test_split(X, Y2, test_size=test_th, shuffle=True)
sc = StandardScaler()
sc.fit(x_train)

x_train = sc.transform(x_train)
x_test = sc.transform(x_test)

# %%
classificator3 = tf.keras.Sequential()
classificator3.add(layers.LSTM(nLSTMs, activation='relu', input_shape=(X.shape[1], 1)))
# classificator3.add(layers.Dense(2, activation='relu'))
classificator3.add(layers.Dense(1, activation='sigmoid'))

classificator3.compile(optimizer=tf.keras.optimizers.Adam(), loss='binary_crossentropy', 
                        metrics =['accuracy', tf.keras.metrics.Precision(),tf.keras.metrics.Recall() ])
#                        metrics =['accuracy'])

classificator3.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_2 (LSTM)               (None, 30)                3840
#
#  dense_2 (Dense)             (None, 1)                 31
#
# =================================================================
# Total params: 3,871
# Trainable params: 3,871
# Non-trainable params: 0
# _________________________________________________________________

# %%
class3_hist = classificator3.fit(x_train, y_train.reshape(-1,1), class_weight={0:1, 1:3}, epochs=nepochs, callbacks= [callback])
# Out:
# Epoch 1/300
# 92/92 [==============================] - 2s 6ms/step - loss: 0.9329 - accuracy: 0.7442 - precision_2: 0.3139 - recall_2: 0.2644
# Epoch 2/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.8329 - accuracy: 0.8090 - precision_2: 0.5139 - recall_2: 0.3555
# Epoch 3/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.8083 - accuracy: 0.8012 - precision_2: 0.4868 - recall_2: 0.3888
# Epoch 4/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.7922 - accuracy: 0.7940 - precision_2: 0.4677 - recall_2: 0.4186
# Epoch 5/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.7770 - accuracy: 0.7916 - precision_2: 0.4627 - recall_2: 0.4343
# Epoch 6/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.7690 - accuracy: 0.7957 - precision_2: 0.4737 - recall_2: 0.4413
# Epoch 7/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.7549 - accuracy: 0.7821 - precision_2: 0.4437 - recall_2: 0.4694
# Epoch 8/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.7406 - accuracy: 0.7729 - precision_2: 0.4277 - recall_2: 0.4921
# Epoch 9/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.7296 - accuracy: 0.7630 - precision_2: 0.4139 - recall_2: 0.5219
# Epoch 10/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.7210 - accuracy: 0.7527 - precision_2: 0.4063 - recall_2: 0.5849
# Epoch 11/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.7142 - accuracy: 0.7510 - precision_2: 0.4083 - recall_2: 0.6200
# Epoch 12/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.6992 - accuracy: 0.7551 - precision_2: 0.4158 - recall_2: 0.6357
# Epoch 13/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.6866 - accuracy: 0.7507 - precision_2: 0.4149 - recall_2: 0.6830
# Epoch 14/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.6758 - accuracy: 0.7541 - precision_2: 0.4204 - recall_2: 0.6935
# Epoch 15/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.6548 - accuracy: 0.7660 - precision_2: 0.4377 - recall_2: 0.7075
# Epoch 16/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.6352 - accuracy: 0.7688 - precision_2: 0.4448 - recall_2: 0.7548
# Epoch 17/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.6118 - accuracy: 0.7715 - precision_2: 0.4502 - recall_2: 0.7828
# Epoch 18/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.6044 - accuracy: 0.7817 - precision_2: 0.4648 - recall_2: 0.7968
# Epoch 19/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.5791 - accuracy: 0.7807 - precision_2: 0.4639 - recall_2: 0.8091
# Epoch 20/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.5576 - accuracy: 0.7858 - precision_2: 0.4715 - recall_2: 0.8249
# Epoch 21/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.5511 - accuracy: 0.7889 - precision_2: 0.4759 - recall_2: 0.8284
# Epoch 22/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.5299 - accuracy: 0.8008 - precision_2: 0.4932 - recall_2: 0.8284
# Epoch 23/300
# 92/92 [==============================] - 1s 8ms/step - loss: 0.5194 - accuracy: 0.8114 - precision_2: 0.5094 - recall_2: 0.8529
# Epoch 24/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.5175 - accuracy: 0.8196 - precision_2: 0.5228 - recall_2: 0.8441
# Epoch 25/300
# 92/92 [==============================] - 1s 8ms/step - loss: 0.4900 - accuracy: 0.8257 - precision_2: 0.5333 - recall_2: 0.8424
# Epoch 26/300
# 92/92 [==============================] - 1s 8ms/step - loss: 0.5445 - accuracy: 0.8083 - precision_2: 0.5049 - recall_2: 0.8109
# Epoch 27/300
# 92/92 [==============================] - 1s 8ms/step - loss: 0.4858 - accuracy: 0.8250 - precision_2: 0.5307 - recall_2: 0.8774
# Epoch 28/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.4778 - accuracy: 0.8295 - precision_2: 0.5386 - recall_2: 0.8669
# Epoch 29/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.4545 - accuracy: 0.8472 - precision_2: 0.5709 - recall_2: 0.8669
# Epoch 30/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.4409 - accuracy: 0.8452 - precision_2: 0.5661 - recall_2: 0.8774
# Epoch 31/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.4461 - accuracy: 0.8472 - precision_2: 0.5708 - recall_2: 0.8687
# Epoch 32/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.4396 - accuracy: 0.8557 - precision_2: 0.5873 - recall_2: 0.8722
# Epoch 33/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.4301 - accuracy: 0.8550 - precision_2: 0.5853 - recall_2: 0.8774
# Epoch 34/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.4071 - accuracy: 0.8666 - precision_2: 0.6066 - recall_2: 0.8967
# Epoch 35/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.4190 - accuracy: 0.8602 - precision_2: 0.5964 - recall_2: 0.8722
# Epoch 36/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.4049 - accuracy: 0.8629 - precision_2: 0.5995 - recall_2: 0.8914
# Epoch 37/300
# 92/92 [==============================] - 1s 8ms/step - loss: 0.4275 - accuracy: 0.8687 - precision_2: 0.6131 - recall_2: 0.8827
# Epoch 38/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.4064 - accuracy: 0.8605 - precision_2: 0.5964 - recall_2: 0.8774
# Epoch 39/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.3917 - accuracy: 0.8735 - precision_2: 0.6232 - recall_2: 0.8862
# Epoch 40/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.3781 - accuracy: 0.8772 - precision_2: 0.6311 - recall_2: 0.8897
# Epoch 41/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.3724 - accuracy: 0.8789 - precision_2: 0.6340 - recall_2: 0.8949
# Epoch 42/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.3649 - accuracy: 0.8830 - precision_2: 0.6404 - recall_2: 0.9107
# Epoch 43/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.3546 - accuracy: 0.8861 - precision_2: 0.6506 - recall_2: 0.8967
# Epoch 44/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.4720 - accuracy: 0.8568 - precision_2: 0.5913 - recall_2: 0.8564
# Epoch 45/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.3709 - accuracy: 0.8799 - precision_2: 0.6357 - recall_2: 0.8984
# Epoch 46/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.3694 - accuracy: 0.8871 - precision_2: 0.6511 - recall_2: 0.9054
# Epoch 47/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.3570 - accuracy: 0.8861 - precision_2: 0.6487 - recall_2: 0.9054
# Epoch 48/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.3451 - accuracy: 0.8939 - precision_2: 0.6641 - recall_2: 0.9212
# Epoch 49/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.3455 - accuracy: 0.8902 - precision_2: 0.6570 - recall_2: 0.9124
# Epoch 50/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.3535 - accuracy: 0.8854 - precision_2: 0.6474 - recall_2: 0.9037
# Epoch 51/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.3391 - accuracy: 0.8922 - precision_2: 0.6600 - recall_2: 0.9212
# Epoch 52/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.3349 - accuracy: 0.8939 - precision_2: 0.6641 - recall_2: 0.9212
# Epoch 53/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.3359 - accuracy: 0.8915 - precision_2: 0.6607 - recall_2: 0.9107
# Epoch 54/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.3245 - accuracy: 0.8977 - precision_2: 0.6735 - recall_2: 0.9212
# Epoch 55/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.3281 - accuracy: 0.8929 - precision_2: 0.6650 - recall_2: 0.9072
# Epoch 56/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.3306 - accuracy: 0.8926 - precision_2: 0.6600 - recall_2: 0.9247
# Epoch 57/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.3093 - accuracy: 0.9042 - precision_2: 0.6859 - recall_2: 0.9370
# Epoch 58/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.3137 - accuracy: 0.8987 - precision_2: 0.6739 - recall_2: 0.9299
# Epoch 59/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.3160 - accuracy: 0.8990 - precision_2: 0.6779 - recall_2: 0.9177
# Epoch 60/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.3043 - accuracy: 0.8973 - precision_2: 0.6713 - recall_2: 0.9264
# Epoch 61/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.2914 - accuracy: 0.9065 - precision_2: 0.6921 - recall_2: 0.9370
# Epoch 62/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.3034 - accuracy: 0.9052 - precision_2: 0.6905 - recall_2: 0.9299
# Epoch 63/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.3170 - accuracy: 0.9004 - precision_2: 0.6805 - recall_2: 0.9212
# Epoch 64/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.2860 - accuracy: 0.9083 - precision_2: 0.6961 - recall_2: 0.9387
# Epoch 65/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.2933 - accuracy: 0.9093 - precision_2: 0.7004 - recall_2: 0.9335
# Epoch 66/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.2826 - accuracy: 0.9096 - precision_2: 0.6967 - recall_2: 0.9492
# Epoch 67/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.2888 - accuracy: 0.9048 - precision_2: 0.6911 - recall_2: 0.9247
# Epoch 68/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.2919 - accuracy: 0.9014 - precision_2: 0.6822 - recall_2: 0.9247
# Epoch 69/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.2705 - accuracy: 0.9154 - precision_2: 0.7133 - recall_2: 0.9457
# Epoch 70/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.2744 - accuracy: 0.9137 - precision_2: 0.7081 - recall_2: 0.9475
# Epoch 71/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.2704 - accuracy: 0.9144 - precision_2: 0.7116 - recall_2: 0.9422
# Epoch 72/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.2657 - accuracy: 0.9181 - precision_2: 0.7198 - recall_2: 0.9492
# Epoch 73/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.2674 - accuracy: 0.9175 - precision_2: 0.7202 - recall_2: 0.9422
# Epoch 74/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.2645 - accuracy: 0.9137 - precision_2: 0.7065 - recall_2: 0.9527
# Epoch 75/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.2753 - accuracy: 0.9164 - precision_2: 0.7168 - recall_2: 0.9440
# Epoch 76/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.2661 - accuracy: 0.9144 - precision_2: 0.7111 - recall_2: 0.9440
# Epoch 77/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.2761 - accuracy: 0.9123 - precision_2: 0.7082 - recall_2: 0.9352
# Epoch 78/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.2428 - accuracy: 0.9226 - precision_2: 0.7306 - recall_2: 0.9545
# Epoch 79/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.2591 - accuracy: 0.9219 - precision_2: 0.7311 - recall_2: 0.9475
# Epoch 80/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.2531 - accuracy: 0.9212 - precision_2: 0.7261 - recall_2: 0.9562
# Epoch 81/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.2434 - accuracy: 0.9205 - precision_2: 0.7265 - recall_2: 0.9492
# Epoch 82/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.2255 - accuracy: 0.9270 - precision_2: 0.7422 - recall_2: 0.9580
# Epoch 83/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.2651 - accuracy: 0.9185 - precision_2: 0.7268 - recall_2: 0.9317
# Epoch 84/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.2312 - accuracy: 0.9256 - precision_2: 0.7395 - recall_2: 0.9545
# Epoch 85/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.2317 - accuracy: 0.9280 - precision_2: 0.7432 - recall_2: 0.9632
# Epoch 86/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.2363 - accuracy: 0.9236 - precision_2: 0.7361 - recall_2: 0.9475
# Epoch 87/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.2291 - accuracy: 0.9297 - precision_2: 0.7531 - recall_2: 0.9510
# Epoch 88/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.2159 - accuracy: 0.9359 - precision_2: 0.7656 - recall_2: 0.9667
# Epoch 89/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.2321 - accuracy: 0.9291 - precision_2: 0.7443 - recall_2: 0.9685
# Epoch 90/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.2223 - accuracy: 0.9318 - precision_2: 0.7573 - recall_2: 0.9562
# Epoch 91/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.2170 - accuracy: 0.9338 - precision_2: 0.7644 - recall_2: 0.9545
# Epoch 92/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.2344 - accuracy: 0.9239 - precision_2: 0.7358 - recall_2: 0.9510
# Epoch 93/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.2243 - accuracy: 0.9297 - precision_2: 0.7510 - recall_2: 0.9562
# Epoch 94/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.2431 - accuracy: 0.9222 - precision_2: 0.7290 - recall_2: 0.9562
# Epoch 95/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.2227 - accuracy: 0.9338 - precision_2: 0.7651 - recall_2: 0.9527
# Epoch 96/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.2042 - accuracy: 0.9342 - precision_2: 0.7610 - recall_2: 0.9650
# Epoch 97/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.2414 - accuracy: 0.9198 - precision_2: 0.7270 - recall_2: 0.9422
# Epoch 98/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.2033 - accuracy: 0.9325 - precision_2: 0.7565 - recall_2: 0.9632
# Epoch 99/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.2022 - accuracy: 0.9403 - precision_2: 0.7789 - recall_2: 0.9685
# Epoch 100/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.1941 - accuracy: 0.9417 - precision_2: 0.7857 - recall_2: 0.9632
# Epoch 101/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.2051 - accuracy: 0.9393 - precision_2: 0.7779 - recall_2: 0.9632
# Epoch 102/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.1944 - accuracy: 0.9376 - precision_2: 0.7709 - recall_2: 0.9667
# Epoch 103/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.1949 - accuracy: 0.9441 - precision_2: 0.7911 - recall_2: 0.9685
# Epoch 104/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.2083 - accuracy: 0.9372 - precision_2: 0.7737 - recall_2: 0.9580
# Epoch 105/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.4837 - accuracy: 0.8707 - precision_2: 0.6162 - recall_2: 0.8914
# Epoch 106/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.2887 - accuracy: 0.9127 - precision_2: 0.7103 - recall_2: 0.9317
# Epoch 107/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.2195 - accuracy: 0.9301 - precision_2: 0.7577 - recall_2: 0.9422
# Epoch 108/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.2113 - accuracy: 0.9342 - precision_2: 0.7647 - recall_2: 0.9562
# Epoch 109/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.2027 - accuracy: 0.9349 - precision_2: 0.7639 - recall_2: 0.9632
# Epoch 110/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.2102 - accuracy: 0.9369 - precision_2: 0.7749 - recall_2: 0.9527

# %%
model.save('classificator3.model')
# Out:
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: classificator3.model/assets
# INFO:tensorflow:Assets written to: classificator3.model/assets

# %%
yp = classificator3.predict(x_test)
yp_class = np.round(yp)
score = classificator3.evaluate(x_test, y_test, verbose=0)
# Out:
# 23/23 [==============================] - 0s 3ms/step

# %%
print(f"Accuracy:  {score[1]*100:.2f}%")
print(f"Precision: {score[2]*100:.2f}%")
print(f"Recall:    {score[3]*100:.2f}%")
# Out:
# Accuracy:  92.51%
# Precision: 75.64%
# Recall:    87.41%

# %%
print(confusion_matrix(y_test, yp_class))
# Out:
# [[561  38]
#  [ 17 118]]

# %%
from sklearn.metrics import roc_curve, auc

# %%
y_pred_keras = yp.ravel()

# %%
nsteps=24
nLSTMs = 15

X, Y, Y2 = getTensors(data_lagged, 'target', nsteps)

(x_train, x_test, y_train, y_test) = train_test_split(X, Y2, test_size=test_th, shuffle=True)
sc = StandardScaler()
sc.fit(x_train)

x_train = sc.transform(x_train)
x_test = sc.transform(x_test)

# %%
classificator4 = tf.keras.Sequential()
classificator4.add(layers.LSTM(nLSTMs, activation='relu', input_shape=(X.shape[1], 1)))
# classificator4.add(layers.Dense(2, activation='relu'))
classificator4.add(layers.Dense(1, activation='sigmoid'))
classificator4.compile(optimizer=tf.keras.optimizers.Adam(), loss='binary_crossentropy', 
                       metrics =['accuracy', tf.keras.metrics.Precision(),tf.keras.metrics.Recall() ])

classificator4.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_3 (LSTM)               (None, 15)                1020
#
#  dense_3 (Dense)             (None, 1)                 16
#
# =================================================================
# Total params: 1,036
# Trainable params: 1,036
# Non-trainable params: 0
# _________________________________________________________________

# %%
class4_hist = classificator4.fit(x_train, y_train.reshape(-1,1), epochs=300, callbacks=[callback])
yp = classificator4.predict(x_test)
yp_class = np.round(yp)
score = classificator4.evaluate(x_test, y_test, verbose=0)
# Out:
# Epoch 1/300
# 92/92 [==============================] - 2s 6ms/step - loss: 0.6486 - accuracy: 0.6791 - precision_3: 0.2372 - recall_3: 0.3071
# Epoch 2/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.4662 - accuracy: 0.8090 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 3/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.4353 - accuracy: 0.8087 - precision_3: 0.3333 - recall_3: 0.0018
# Epoch 4/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.4256 - accuracy: 0.8087 - precision_3: 0.4848 - recall_3: 0.0286
# Epoch 5/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.4159 - accuracy: 0.8076 - precision_3: 0.4796 - recall_3: 0.0839
# Epoch 6/300
# 92/92 [==============================] - 1s 5ms/step - loss: 0.4085 - accuracy: 0.8128 - precision_3: 0.5374 - recall_3: 0.1411
# Epoch 7/300
# 92/92 [==============================] - 0s 5ms/step - loss: 0.4037 - accuracy: 0.8182 - precision_3: 0.5616 - recall_3: 0.2196
# Epoch 8/300
# 92/92 [==============================] - 0s 5ms/step - loss: 0.4003 - accuracy: 0.8158 - precision_3: 0.5521 - recall_3: 0.1893
# Epoch 9/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.3974 - accuracy: 0.8209 - precision_3: 0.5709 - recall_3: 0.2518
# Epoch 10/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.3962 - accuracy: 0.8186 - precision_3: 0.5619 - recall_3: 0.2268
# Epoch 11/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.3922 - accuracy: 0.8203 - precision_3: 0.5642 - recall_3: 0.2589
# Epoch 12/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.3904 - accuracy: 0.8199 - precision_3: 0.5708 - recall_3: 0.2304
# Epoch 13/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.3877 - accuracy: 0.8206 - precision_3: 0.5720 - recall_3: 0.2411
# Epoch 14/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.3862 - accuracy: 0.8206 - precision_3: 0.5685 - recall_3: 0.2518
# Epoch 15/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.3863 - accuracy: 0.8203 - precision_3: 0.5663 - recall_3: 0.2518
# Epoch 16/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.3853 - accuracy: 0.8216 - precision_3: 0.5768 - recall_3: 0.2482
# Epoch 17/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.3837 - accuracy: 0.8216 - precision_3: 0.5743 - recall_3: 0.2554
# Epoch 18/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.3793 - accuracy: 0.8233 - precision_3: 0.5868 - recall_3: 0.2536
# Epoch 19/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.3796 - accuracy: 0.8244 - precision_3: 0.5904 - recall_3: 0.2625
# Epoch 20/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.3764 - accuracy: 0.8237 - precision_3: 0.5956 - recall_3: 0.2393
# Epoch 21/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.3770 - accuracy: 0.8274 - precision_3: 0.6195 - recall_3: 0.2500
# Epoch 22/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.3749 - accuracy: 0.8257 - precision_3: 0.6150 - recall_3: 0.2339
# Epoch 23/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.3718 - accuracy: 0.8284 - precision_3: 0.6301 - recall_3: 0.2464
# Epoch 24/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.3699 - accuracy: 0.8278 - precision_3: 0.6303 - recall_3: 0.2375
# Epoch 25/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.3702 - accuracy: 0.8284 - precision_3: 0.6432 - recall_3: 0.2286
# Epoch 26/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.3694 - accuracy: 0.8295 - precision_3: 0.6456 - recall_3: 0.2375
# Epoch 27/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.3679 - accuracy: 0.8298 - precision_3: 0.6517 - recall_3: 0.2339
# Epoch 28/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.3634 - accuracy: 0.8315 - precision_3: 0.6542 - recall_3: 0.2500
# Epoch 29/300
# 92/92 [==============================] - 1s 5ms/step - loss: 0.3681 - accuracy: 0.8302 - precision_3: 0.6490 - recall_3: 0.2411
# Epoch 30/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.3654 - accuracy: 0.8302 - precision_3: 0.6409 - recall_3: 0.2518
# Epoch 31/300
# 92/92 [==============================] - 0s 5ms/step - loss: 0.3608 - accuracy: 0.8315 - precision_3: 0.6602 - recall_3: 0.2429
# Epoch 32/300
# 92/92 [==============================] - 0s 5ms/step - loss: 0.3581 - accuracy: 0.8339 - precision_3: 0.6995 - recall_3: 0.2286
# Epoch 33/300
# 92/92 [==============================] - 1s 5ms/step - loss: 0.3599 - accuracy: 0.8308 - precision_3: 0.6391 - recall_3: 0.2625
# Epoch 34/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.3589 - accuracy: 0.8295 - precision_3: 0.6442 - recall_3: 0.2393
# Epoch 35/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.3592 - accuracy: 0.8356 - precision_3: 0.6875 - recall_3: 0.2554
# Epoch 36/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.3517 - accuracy: 0.8363 - precision_3: 0.6980 - recall_3: 0.2518
# Epoch 37/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.3493 - accuracy: 0.8336 - precision_3: 0.6748 - recall_3: 0.2482
# Epoch 38/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.3522 - accuracy: 0.8325 - precision_3: 0.6635 - recall_3: 0.2500
# Epoch 39/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.3490 - accuracy: 0.8366 - precision_3: 0.7015 - recall_3: 0.2518
# Epoch 40/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.3466 - accuracy: 0.8356 - precision_3: 0.7010 - recall_3: 0.2429
# Epoch 41/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.3471 - accuracy: 0.8356 - precision_3: 0.6893 - recall_3: 0.2536
# Epoch 42/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.3487 - accuracy: 0.8336 - precision_3: 0.6622 - recall_3: 0.2625
# Epoch 43/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.3446 - accuracy: 0.8363 - precision_3: 0.7020 - recall_3: 0.2482
# Epoch 44/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.3423 - accuracy: 0.8373 - precision_3: 0.6930 - recall_3: 0.2661
# Epoch 45/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.3424 - accuracy: 0.8359 - precision_3: 0.6872 - recall_3: 0.2589
# Epoch 46/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.3421 - accuracy: 0.8390 - precision_3: 0.7157 - recall_3: 0.2607
# Epoch 47/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.3422 - accuracy: 0.8380 - precision_3: 0.7136 - recall_3: 0.2536
# Epoch 48/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.3405 - accuracy: 0.8377 - precision_3: 0.6981 - recall_3: 0.2643
# Epoch 49/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.3428 - accuracy: 0.8377 - precision_3: 0.6892 - recall_3: 0.2732
# Epoch 50/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.3413 - accuracy: 0.8359 - precision_3: 0.6837 - recall_3: 0.2625
# Epoch 51/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.3380 - accuracy: 0.8387 - precision_3: 0.7186 - recall_3: 0.2554
# Epoch 52/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.3380 - accuracy: 0.8407 - precision_3: 0.7268 - recall_3: 0.2661
# Epoch 53/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.3374 - accuracy: 0.8387 - precision_3: 0.6968 - recall_3: 0.2750
# Epoch 54/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.3360 - accuracy: 0.8366 - precision_3: 0.7015 - recall_3: 0.2518
# Epoch 55/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.3368 - accuracy: 0.8400 - precision_3: 0.7116 - recall_3: 0.2732
# Epoch 56/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.3379 - accuracy: 0.8363 - precision_3: 0.6802 - recall_3: 0.2696
# Epoch 57/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.3367 - accuracy: 0.8407 - precision_3: 0.7183 - recall_3: 0.2732
# Epoch 58/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.3374 - accuracy: 0.8383 - precision_3: 0.6972 - recall_3: 0.2714
# Epoch 59/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.3338 - accuracy: 0.8387 - precision_3: 0.7005 - recall_3: 0.2714
# Epoch 60/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.3361 - accuracy: 0.8397 - precision_3: 0.7273 - recall_3: 0.2571
# Epoch 61/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.3338 - accuracy: 0.8370 - precision_3: 0.7010 - recall_3: 0.2554
# Epoch 62/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.3314 - accuracy: 0.8407 - precision_3: 0.7143 - recall_3: 0.2768
# Epoch 63/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.3329 - accuracy: 0.8397 - precision_3: 0.7143 - recall_3: 0.2679
# Epoch 64/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.3311 - accuracy: 0.8411 - precision_3: 0.7156 - recall_3: 0.2786
# Epoch 65/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.3311 - accuracy: 0.8438 - precision_3: 0.7318 - recall_3: 0.2875
# Epoch 66/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.3291 - accuracy: 0.8411 - precision_3: 0.7043 - recall_3: 0.2893
# Epoch 67/300
# 92/92 [==============================] - 0s 5ms/step - loss: 0.3325 - accuracy: 0.8394 - precision_3: 0.6996 - recall_3: 0.2786
# Epoch 68/300
# 92/92 [==============================] - 0s 5ms/step - loss: 0.3274 - accuracy: 0.8424 - precision_3: 0.7333 - recall_3: 0.2750
# Epoch 69/300
# 92/92 [==============================] - 1s 5ms/step - loss: 0.3299 - accuracy: 0.8404 - precision_3: 0.7150 - recall_3: 0.2732
# Epoch 70/300
# 92/92 [==============================] - 0s 5ms/step - loss: 0.3303 - accuracy: 0.8363 - precision_3: 0.6754 - recall_3: 0.2750
# Epoch 71/300
# 92/92 [==============================] - 1s 5ms/step - loss: 0.3260 - accuracy: 0.8448 - precision_3: 0.7586 - recall_3: 0.2750
# Epoch 72/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.3276 - accuracy: 0.8445 - precision_3: 0.7281 - recall_3: 0.2964
# Epoch 73/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.3250 - accuracy: 0.8455 - precision_3: 0.7443 - recall_3: 0.2911
# Epoch 74/300
# 92/92 [==============================] - 0s 5ms/step - loss: 0.3318 - accuracy: 0.8428 - precision_3: 0.7143 - recall_3: 0.2946
# Epoch 75/300
# 92/92 [==============================] - 1s 5ms/step - loss: 0.3257 - accuracy: 0.8407 - precision_3: 0.7104 - recall_3: 0.2804
# Epoch 76/300
# 92/92 [==============================] - 1s 5ms/step - loss: 0.3276 - accuracy: 0.8441 - precision_3: 0.7173 - recall_3: 0.3036
# Epoch 77/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.3262 - accuracy: 0.8404 - precision_3: 0.7072 - recall_3: 0.2804
# Epoch 78/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.3208 - accuracy: 0.8441 - precision_3: 0.7289 - recall_3: 0.2929
# Epoch 79/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.3252 - accuracy: 0.8452 - precision_3: 0.7431 - recall_3: 0.2893
# Epoch 80/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.3354 - accuracy: 0.8400 - precision_3: 0.6842 - recall_3: 0.3018
# Epoch 81/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.3264 - accuracy: 0.8445 - precision_3: 0.7281 - recall_3: 0.2964
# Epoch 82/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.3250 - accuracy: 0.8438 - precision_3: 0.7318 - recall_3: 0.2875
# Epoch 83/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.3219 - accuracy: 0.8435 - precision_3: 0.7512 - recall_3: 0.2696
# Epoch 84/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.3241 - accuracy: 0.8469 - precision_3: 0.7424 - recall_3: 0.3036
# Epoch 85/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.3191 - accuracy: 0.8458 - precision_3: 0.7411 - recall_3: 0.2964
# Epoch 86/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.3177 - accuracy: 0.8465 - precision_3: 0.7434 - recall_3: 0.3000
# Epoch 87/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.3208 - accuracy: 0.8417 - precision_3: 0.7105 - recall_3: 0.2893
# Epoch 88/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.3149 - accuracy: 0.8458 - precision_3: 0.7389 - recall_3: 0.2982
# Epoch 89/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.3252 - accuracy: 0.8445 - precision_3: 0.7301 - recall_3: 0.2946
# Epoch 90/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.3130 - accuracy: 0.8472 - precision_3: 0.7569 - recall_3: 0.2946
# Epoch 91/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.3118 - accuracy: 0.8492 - precision_3: 0.7658 - recall_3: 0.3036
# Epoch 92/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.3173 - accuracy: 0.8441 - precision_3: 0.7249 - recall_3: 0.2964
# Epoch 93/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.3182 - accuracy: 0.8482 - precision_3: 0.7489 - recall_3: 0.3089
# Epoch 94/300
# 92/92 [==============================] - 1s 8ms/step - loss: 0.3119 - accuracy: 0.8469 - precision_3: 0.7511 - recall_3: 0.2964
# Epoch 95/300
# 92/92 [==============================] - 1s 8ms/step - loss: 0.3109 - accuracy: 0.8499 - precision_3: 0.7586 - recall_3: 0.3143
# Epoch 96/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.3128 - accuracy: 0.8482 - precision_3: 0.7556 - recall_3: 0.3036
# Epoch 97/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.3107 - accuracy: 0.8482 - precision_3: 0.7489 - recall_3: 0.3089
# Epoch 98/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.3072 - accuracy: 0.8492 - precision_3: 0.7479 - recall_3: 0.3179
# Epoch 99/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.3102 - accuracy: 0.8496 - precision_3: 0.7576 - recall_3: 0.3125
# Epoch 100/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.3087 - accuracy: 0.8469 - precision_3: 0.7303 - recall_3: 0.3143
# Epoch 101/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.3156 - accuracy: 0.8435 - precision_3: 0.6980 - recall_3: 0.3179
# Epoch 102/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.3107 - accuracy: 0.8472 - precision_3: 0.7617 - recall_3: 0.2911
# Epoch 103/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.3085 - accuracy: 0.8503 - precision_3: 0.7531 - recall_3: 0.3214
# Epoch 104/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.3064 - accuracy: 0.8516 - precision_3: 0.7510 - recall_3: 0.3339
# Epoch 105/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.3009 - accuracy: 0.8530 - precision_3: 0.7817 - recall_3: 0.3196
# Epoch 106/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.3219 - accuracy: 0.8452 - precision_3: 0.7431 - recall_3: 0.2893
# Epoch 107/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.3047 - accuracy: 0.8527 - precision_3: 0.7712 - recall_3: 0.3250
# Epoch 108/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.2986 - accuracy: 0.8520 - precision_3: 0.7540 - recall_3: 0.3339
# Epoch 109/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.3034 - accuracy: 0.8520 - precision_3: 0.7461 - recall_3: 0.3411
# Epoch 110/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.3008 - accuracy: 0.8506 - precision_3: 0.7075 - recall_3: 0.3714
# Epoch 111/300
# 92/92 [==============================] - 1s 8ms/step - loss: 0.3050 - accuracy: 0.8489 - precision_3: 0.7143 - recall_3: 0.3482
# Epoch 112/300
# 92/92 [==============================] - 1s 8ms/step - loss: 0.2979 - accuracy: 0.8544 - precision_3: 0.7418 - recall_3: 0.3643
# Epoch 113/300
# 92/92 [==============================] - 1s 8ms/step - loss: 0.2929 - accuracy: 0.8537 - precision_3: 0.7176 - recall_3: 0.3857
# Epoch 114/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.2897 - accuracy: 0.8581 - precision_3: 0.7323 - recall_3: 0.4054
# Epoch 115/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.2957 - accuracy: 0.8523 - precision_3: 0.7055 - recall_3: 0.3893
# Epoch 116/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.2870 - accuracy: 0.8629 - precision_3: 0.7438 - recall_3: 0.4304
# Epoch 117/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.2919 - accuracy: 0.8564 - precision_3: 0.7324 - recall_3: 0.3911
# Epoch 118/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.2894 - accuracy: 0.8591 - precision_3: 0.7168 - recall_3: 0.4339
# Epoch 119/300
# 92/92 [==============================] - 1s 8ms/step - loss: 0.2885 - accuracy: 0.8564 - precision_3: 0.7179 - recall_3: 0.4089
# Epoch 120/300
# 92/92 [==============================] - 1s 8ms/step - loss: 0.2876 - accuracy: 0.8585 - precision_3: 0.7316 - recall_3: 0.4089
# Epoch 121/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.2968 - accuracy: 0.8571 - precision_3: 0.7196 - recall_3: 0.4125
# Epoch 122/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.2880 - accuracy: 0.8568 - precision_3: 0.7465 - recall_3: 0.3786
# Epoch 123/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.2891 - accuracy: 0.8598 - precision_3: 0.7307 - recall_3: 0.4214
# Epoch 124/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.2865 - accuracy: 0.8632 - precision_3: 0.7291 - recall_3: 0.4518
# Epoch 125/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.2826 - accuracy: 0.8704 - precision_3: 0.7473 - recall_3: 0.4857
# Epoch 126/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.2844 - accuracy: 0.8639 - precision_3: 0.7320 - recall_3: 0.4536
# Epoch 127/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.2831 - accuracy: 0.8612 - precision_3: 0.7257 - recall_3: 0.4393
# Epoch 128/300
# 92/92 [==============================] - 1s 5ms/step - loss: 0.2828 - accuracy: 0.8615 - precision_3: 0.7238 - recall_3: 0.4446
# Epoch 129/300
# 92/92 [==============================] - 1s 5ms/step - loss: 0.2769 - accuracy: 0.8707 - precision_3: 0.7670 - recall_3: 0.4643
# Epoch 130/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.2760 - accuracy: 0.8687 - precision_3: 0.7451 - recall_3: 0.4750
# Epoch 131/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.2823 - accuracy: 0.8619 - precision_3: 0.7221 - recall_3: 0.4500
# Epoch 132/300
# 92/92 [==============================] - 1s 5ms/step - loss: 0.2725 - accuracy: 0.8690 - precision_3: 0.7431 - recall_3: 0.4804
# Epoch 133/300
# 92/92 [==============================] - 1s 5ms/step - loss: 0.2713 - accuracy: 0.8704 - precision_3: 0.7500 - recall_3: 0.4821
# Epoch 134/300
# 92/92 [==============================] - 1s 5ms/step - loss: 0.2680 - accuracy: 0.8714 - precision_3: 0.7563 - recall_3: 0.4821
# Epoch 135/300
# 92/92 [==============================] - 1s 5ms/step - loss: 0.2778 - accuracy: 0.8697 - precision_3: 0.7557 - recall_3: 0.4696
# Epoch 136/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.2667 - accuracy: 0.8769 - precision_3: 0.7558 - recall_3: 0.5250
# Epoch 137/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.2683 - accuracy: 0.8694 - precision_3: 0.7360 - recall_3: 0.4929
# Epoch 138/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.2699 - accuracy: 0.8772 - precision_3: 0.7564 - recall_3: 0.5268
# Epoch 139/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.2708 - accuracy: 0.8748 - precision_3: 0.7703 - recall_3: 0.4911
# Epoch 140/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.2695 - accuracy: 0.8772 - precision_3: 0.7732 - recall_3: 0.5054
# Epoch 141/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.2744 - accuracy: 0.8714 - precision_3: 0.7414 - recall_3: 0.5018
# Epoch 142/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.2644 - accuracy: 0.8738 - precision_3: 0.7513 - recall_3: 0.5071
# Epoch 143/300
# 92/92 [==============================] - 1s 5ms/step - loss: 0.2576 - accuracy: 0.8765 - precision_3: 0.7538 - recall_3: 0.5250
# Epoch 144/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.2538 - accuracy: 0.8823 - precision_3: 0.7590 - recall_3: 0.5625
# Epoch 145/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.2539 - accuracy: 0.8806 - precision_3: 0.7500 - recall_3: 0.5625
# Epoch 146/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.2526 - accuracy: 0.8823 - precision_3: 0.7792 - recall_3: 0.5357
# Epoch 147/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.2498 - accuracy: 0.8837 - precision_3: 0.7639 - recall_3: 0.5661
# Epoch 148/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.2462 - accuracy: 0.8881 - precision_3: 0.7857 - recall_3: 0.5696
# Epoch 149/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.2535 - accuracy: 0.8799 - precision_3: 0.7549 - recall_3: 0.5500
# Epoch 150/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.2444 - accuracy: 0.8823 - precision_3: 0.7681 - recall_3: 0.5500
# Epoch 151/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.2473 - accuracy: 0.8888 - precision_3: 0.7696 - recall_3: 0.5964
# Epoch 152/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.2523 - accuracy: 0.8868 - precision_3: 0.7754 - recall_3: 0.5732
# Epoch 153/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.2473 - accuracy: 0.8851 - precision_3: 0.7674 - recall_3: 0.5714
# Epoch 154/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.2361 - accuracy: 0.8905 - precision_3: 0.7825 - recall_3: 0.5911
# Epoch 155/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.2333 - accuracy: 0.8902 - precision_3: 0.7742 - recall_3: 0.6000
# Epoch 156/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.2334 - accuracy: 0.8878 - precision_3: 0.7667 - recall_3: 0.5929
# Epoch 157/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.2349 - accuracy: 0.8885 - precision_3: 0.7691 - recall_3: 0.5946
# Epoch 158/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.2367 - accuracy: 0.8936 - precision_3: 0.7731 - recall_3: 0.6268
# Epoch 159/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.2284 - accuracy: 0.8922 - precision_3: 0.7699 - recall_3: 0.6214
# Epoch 160/300
# 92/92 [==============================] - 1s 8ms/step - loss: 0.2270 - accuracy: 0.8932 - precision_3: 0.7800 - recall_3: 0.6143
# Epoch 161/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.2259 - accuracy: 0.8946 - precision_3: 0.7783 - recall_3: 0.6268
# Epoch 162/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.2285 - accuracy: 0.8973 - precision_3: 0.7897 - recall_3: 0.6304
# Epoch 163/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.2194 - accuracy: 0.8994 - precision_3: 0.7991 - recall_3: 0.6321
# Epoch 164/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.2171 - accuracy: 0.8963 - precision_3: 0.7759 - recall_3: 0.6429
# Epoch 165/300
# 92/92 [==============================] - 1s 8ms/step - loss: 0.2196 - accuracy: 0.8994 - precision_3: 0.7766 - recall_3: 0.6643
# Epoch 166/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.2162 - accuracy: 0.8987 - precision_3: 0.7903 - recall_3: 0.6393
# Epoch 167/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.2285 - accuracy: 0.8905 - precision_3: 0.7548 - recall_3: 0.6321
# Epoch 168/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.2219 - accuracy: 0.8950 - precision_3: 0.7658 - recall_3: 0.6482
# Epoch 169/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.2166 - accuracy: 0.8997 - precision_3: 0.7879 - recall_3: 0.6500
# Epoch 170/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.2291 - accuracy: 0.8892 - precision_3: 0.7463 - recall_3: 0.6357
# Epoch 171/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.2106 - accuracy: 0.9048 - precision_3: 0.7958 - recall_3: 0.6750
# Epoch 172/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.2176 - accuracy: 0.8987 - precision_3: 0.7828 - recall_3: 0.6500
# Epoch 173/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.2189 - accuracy: 0.9001 - precision_3: 0.7719 - recall_3: 0.6768
# Epoch 174/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.2119 - accuracy: 0.9035 - precision_3: 0.7941 - recall_3: 0.6679
# Epoch 175/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.2674 - accuracy: 0.8888 - precision_3: 0.7600 - recall_3: 0.6107
# Epoch 176/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.2250 - accuracy: 0.8973 - precision_3: 0.7846 - recall_3: 0.6375
# Epoch 177/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.2135 - accuracy: 0.9048 - precision_3: 0.7921 - recall_3: 0.6804
# Epoch 178/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.2122 - accuracy: 0.8984 - precision_3: 0.7764 - recall_3: 0.6571
# Epoch 179/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.2083 - accuracy: 0.9110 - precision_3: 0.8045 - recall_3: 0.7054
# Epoch 180/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.2027 - accuracy: 0.9086 - precision_3: 0.8054 - recall_3: 0.6875
# Epoch 181/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.2092 - accuracy: 0.8990 - precision_3: 0.7716 - recall_3: 0.6696
# Epoch 182/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.2113 - accuracy: 0.9042 - precision_3: 0.7688 - recall_3: 0.7125
# Epoch 183/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.2161 - accuracy: 0.9001 - precision_3: 0.7799 - recall_3: 0.6643
# Epoch 184/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.2001 - accuracy: 0.9076 - precision_3: 0.7955 - recall_3: 0.6946
# Epoch 185/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.1991 - accuracy: 0.9096 - precision_3: 0.7992 - recall_3: 0.7036
# Epoch 186/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.1971 - accuracy: 0.9154 - precision_3: 0.8184 - recall_3: 0.7161
# Epoch 187/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.1951 - accuracy: 0.9147 - precision_3: 0.8163 - recall_3: 0.7143
# Epoch 188/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.1980 - accuracy: 0.9123 - precision_3: 0.7965 - recall_3: 0.7268
# Epoch 189/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.2100 - accuracy: 0.9011 - precision_3: 0.7679 - recall_3: 0.6911
# Epoch 190/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.1940 - accuracy: 0.9113 - precision_3: 0.8012 - recall_3: 0.7125
# Epoch 191/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.1966 - accuracy: 0.9147 - precision_3: 0.8027 - recall_3: 0.7339
# Epoch 192/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.1909 - accuracy: 0.9137 - precision_3: 0.8004 - recall_3: 0.7304
# Epoch 193/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.1905 - accuracy: 0.9158 - precision_3: 0.8075 - recall_3: 0.7339
# Epoch 194/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.1917 - accuracy: 0.9093 - precision_3: 0.7917 - recall_3: 0.7125
# Epoch 195/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.1948 - accuracy: 0.9106 - precision_3: 0.7865 - recall_3: 0.7304
# Epoch 196/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.1913 - accuracy: 0.9181 - precision_3: 0.8125 - recall_3: 0.7429
# Epoch 197/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.1970 - accuracy: 0.9086 - precision_3: 0.7840 - recall_3: 0.7196
# Epoch 198/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.1883 - accuracy: 0.9141 - precision_3: 0.8008 - recall_3: 0.7321
# Epoch 199/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.1874 - accuracy: 0.9171 - precision_3: 0.8042 - recall_3: 0.7482
# Epoch 200/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.1813 - accuracy: 0.9185 - precision_3: 0.8129 - recall_3: 0.7446
# Epoch 201/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.1821 - accuracy: 0.9195 - precision_3: 0.8080 - recall_3: 0.7589
# Epoch 202/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.1873 - accuracy: 0.9195 - precision_3: 0.8115 - recall_3: 0.7536
# Epoch 203/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.1922 - accuracy: 0.9185 - precision_3: 0.8204 - recall_3: 0.7339
# Epoch 204/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.1803 - accuracy: 0.9192 - precision_3: 0.7963 - recall_3: 0.7750
# Epoch 205/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.1793 - accuracy: 0.9181 - precision_3: 0.8187 - recall_3: 0.7339
# Epoch 206/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.1854 - accuracy: 0.9161 - precision_3: 0.7962 - recall_3: 0.7536
# Epoch 207/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.1812 - accuracy: 0.9185 - precision_3: 0.8046 - recall_3: 0.7571
# Epoch 208/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.1745 - accuracy: 0.9253 - precision_3: 0.8235 - recall_3: 0.7750
# Epoch 209/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.1791 - accuracy: 0.9192 - precision_3: 0.8019 - recall_3: 0.7661
# Epoch 210/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.1693 - accuracy: 0.9301 - precision_3: 0.8394 - recall_3: 0.7839
# Epoch 211/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.1711 - accuracy: 0.9280 - precision_3: 0.8262 - recall_3: 0.7893
# Epoch 212/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.1699 - accuracy: 0.9274 - precision_3: 0.8280 - recall_3: 0.7821
# Epoch 213/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.1774 - accuracy: 0.9219 - precision_3: 0.8093 - recall_3: 0.7732
# Epoch 214/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.1726 - accuracy: 0.9277 - precision_3: 0.8258 - recall_3: 0.7875
# Epoch 215/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.1767 - accuracy: 0.9260 - precision_3: 0.8330 - recall_3: 0.7661
# Epoch 216/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.1802 - accuracy: 0.9246 - precision_3: 0.8192 - recall_3: 0.7768
# Epoch 217/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.1742 - accuracy: 0.9246 - precision_3: 0.8216 - recall_3: 0.7732
# Epoch 218/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.1812 - accuracy: 0.9250 - precision_3: 0.8137 - recall_3: 0.7875
# Epoch 219/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.1668 - accuracy: 0.9233 - precision_3: 0.8143 - recall_3: 0.7750
# Epoch 220/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.1744 - accuracy: 0.9216 - precision_3: 0.8173 - recall_3: 0.7589
# Epoch 221/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.1796 - accuracy: 0.9181 - precision_3: 0.7952 - recall_3: 0.7696
# Epoch 222/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.1671 - accuracy: 0.9291 - precision_3: 0.8271 - recall_3: 0.7946
# Epoch 223/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.1672 - accuracy: 0.9267 - precision_3: 0.8273 - recall_3: 0.7786
# Epoch 224/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.1621 - accuracy: 0.9311 - precision_3: 0.8365 - recall_3: 0.7946
# Epoch 225/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.1730 - accuracy: 0.9229 - precision_3: 0.8104 - recall_3: 0.7786
# Epoch 226/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.1657 - accuracy: 0.9308 - precision_3: 0.8349 - recall_3: 0.7946
# Epoch 227/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.1613 - accuracy: 0.9263 - precision_3: 0.8221 - recall_3: 0.7839
# Epoch 228/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.1604 - accuracy: 0.9277 - precision_3: 0.8222 - recall_3: 0.7929
# Epoch 229/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.1903 - accuracy: 0.9151 - precision_3: 0.7802 - recall_3: 0.7732
# Epoch 230/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.1620 - accuracy: 0.9219 - precision_3: 0.8189 - recall_3: 0.7589
# Epoch 231/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.1613 - accuracy: 0.9304 - precision_3: 0.8384 - recall_3: 0.7875
# Epoch 232/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.1575 - accuracy: 0.9297 - precision_3: 0.8242 - recall_3: 0.8036
# Epoch 233/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.1605 - accuracy: 0.9314 - precision_3: 0.8306 - recall_3: 0.8054
# Epoch 234/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.1642 - accuracy: 0.9301 - precision_3: 0.8257 - recall_3: 0.8036
# Epoch 235/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.1668 - accuracy: 0.9260 - precision_3: 0.8254 - recall_3: 0.7768
# Epoch 236/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.1670 - accuracy: 0.9284 - precision_3: 0.8170 - recall_3: 0.8054
# Epoch 237/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.1579 - accuracy: 0.9277 - precision_3: 0.8152 - recall_3: 0.8036
# Epoch 238/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.1847 - accuracy: 0.9192 - precision_3: 0.8030 - recall_3: 0.7643
# Epoch 239/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.1649 - accuracy: 0.9321 - precision_3: 0.8374 - recall_3: 0.8000
# Epoch 240/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.1663 - accuracy: 0.9301 - precision_3: 0.8293 - recall_3: 0.7982
# Epoch 241/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.1831 - accuracy: 0.9314 - precision_3: 0.8343 - recall_3: 0.8000
# Epoch 242/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.1692 - accuracy: 0.9284 - precision_3: 0.8302 - recall_3: 0.7857
# 23/23 [==============================] - 0s 2ms/step

# %%
classificator4.save('classificator4.model')
# Out:
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: classificator4.model/assets
# INFO:tensorflow:Assets written to: classificator4.model/assets

# %%
# print(f"Accuracy {score[1]*100:.2f}%")
print(f"Accuracy:  {score[1]*100:.2f}%")
print(f"Precision: {score[2]*100:.2f}%")
print(f"Recall:    {score[3]*100:.2f}%")
# Out:
# Accuracy:  91.69%
# Precision: 78.52%
# Recall:    80.14%

# %%
print(confusion_matrix(y_test, yp_class))
# Out:
# [[556  32]
#  [ 29 117]]

# %%
cmatrix = confusion_matrix(y_test, yp_class)

plt.figure(figsize=(12.8, 6))
sns.set(font_scale=1.8)
sns.heatmap(cmatrix, annot=True, xticklabels=binlabels, yticklabels=binlabels, annot_kws={"size": 20}, cmap="Blues", fmt="g")
plt.xlabel('Predicted', fontsize = 25, weight='bold');
plt.ylabel('Actual', fontsize = 25, weight='bold');
plt.title(f'Forecast: {nsteps} hour ahead');

plt.savefig('RNN-binary-24h-cmatrix.png')

# %%
from sklearn.metrics import roc_curve, auc

# %%
y_pred_keras = classificator4.predict(x_test).ravel()
# Out:
# 23/23 [==============================] - 0s 2ms/step

# %%
fpr_keras2, tpr_keras2, thresholds_keras2 = roc_curve(y_test, y_pred_keras)
auc_keras2 = auc(fpr_keras2, tpr_keras2)

# %% [markdown]
# ### 24 hours forcasting on four states

# %%
nsteps=24
nLSTMs = 30

X, Y, Y2 = getTensors(data_lagged, 'target', nsteps)

(x_train, x_test, y_train, y_test) = train_test_split(X, Y, test_size=test_th, shuffle=True)
sc = StandardScaler()
sc.fit(x_train)

x_train = sc.transform(x_train)
x_test = sc.transform(x_test)

# %%
model24h = tf.keras.Sequential()
model24h.add(layers.LSTM(nLSTMs, activation='relu', input_shape=(X.shape[1], 1)))
model24h.add(layers.Dense(Y.shape[1], activation='softmax'))
model24h.compile(optimizer=tf.keras.optimizers.Adam(), loss='categorical_crossentropy', 
                 metrics =['accuracy', tf.keras.metrics.Precision(),tf.keras.metrics.Recall() ])
model24h.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_4 (LSTM)               (None, 30)                3840
#
#  dense_4 (Dense)             (None, 4)                 124
#
# =================================================================
# Total params: 3,964
# Trainable params: 3,964
# Non-trainable params: 0
# _________________________________________________________________

# %%
1/data_lagged['target'].value_counts()/len(data_lagged)*10000000
# Out:
# 0.0    1.166509
# 1.0    3.420171
# 2.0    3.560660
# 3.0    6.580696
# Name: target, dtype: float64

# %%
weights= {0:1,1:1,2:4,3:1}

# weights= {0:1.2,1:3.4,2:3.6,3:6.6}
model24h_hist = model24h.fit(x_train, y_train, class_weight=weights, epochs=nepochs, callbacks=[callback], verbose=1)
# Out:
# Epoch 1/300
# 92/92 [==============================] - 3s 6ms/step - loss: 1.9553 - accuracy: 0.1917 - precision_4: 0.3285 - recall_4: 0.0385
# Epoch 2/300
# 92/92 [==============================] - 1s 6ms/step - loss: 1.7423 - accuracy: 0.1941 - precision_4: 0.3362 - recall_4: 0.0928
# Epoch 3/300
# 92/92 [==============================] - 1s 6ms/step - loss: 1.5961 - accuracy: 0.4372 - precision_4: 0.5191 - recall_4: 0.2036
# Epoch 4/300
# 92/92 [==============================] - 1s 6ms/step - loss: 1.5434 - accuracy: 0.4502 - precision_4: 0.5098 - recall_4: 0.2940
# Epoch 5/300
# 92/92 [==============================] - 1s 6ms/step - loss: 1.5280 - accuracy: 0.4202 - precision_4: 0.4282 - recall_4: 0.2012
# Epoch 6/300
# 92/92 [==============================] - 1s 6ms/step - loss: 1.4661 - accuracy: 0.4952 - precision_4: 0.5181 - recall_4: 0.3220
# Epoch 7/300
# 92/92 [==============================] - 1s 6ms/step - loss: 1.4411 - accuracy: 0.5078 - precision_4: 0.5368 - recall_4: 0.3387
# Epoch 8/300
# 92/92 [==============================] - 1s 7ms/step - loss: 1.4201 - accuracy: 0.5078 - precision_4: 0.5387 - recall_4: 0.3510
# Epoch 9/300
# 92/92 [==============================] - 1s 7ms/step - loss: 1.3893 - accuracy: 0.5222 - precision_4: 0.5562 - recall_4: 0.3728
# Epoch 10/300
# 92/92 [==============================] - 1s 6ms/step - loss: 1.3713 - accuracy: 0.5389 - precision_4: 0.5705 - recall_4: 0.3810
# Epoch 11/300
# 92/92 [==============================] - 1s 6ms/step - loss: 1.3313 - accuracy: 0.5624 - precision_4: 0.6063 - recall_4: 0.4386
# Epoch 12/300
# 92/92 [==============================] - 1s 6ms/step - loss: 1.3166 - accuracy: 0.5703 - precision_4: 0.6169 - recall_4: 0.4662
# Epoch 13/300
# 92/92 [==============================] - 1s 6ms/step - loss: 1.2859 - accuracy: 0.5866 - precision_4: 0.6353 - recall_4: 0.4860
# Epoch 14/300
# 92/92 [==============================] - 1s 6ms/step - loss: 1.2564 - accuracy: 0.5958 - precision_4: 0.6385 - recall_4: 0.5007
# Epoch 15/300
# 92/92 [==============================] - 1s 7ms/step - loss: 1.2282 - accuracy: 0.5945 - precision_4: 0.6473 - recall_4: 0.5194
# Epoch 16/300
# 92/92 [==============================] - 1s 6ms/step - loss: 1.1877 - accuracy: 0.6013 - precision_4: 0.6564 - recall_4: 0.5304
# Epoch 17/300
# 92/92 [==============================] - 1s 6ms/step - loss: 1.1602 - accuracy: 0.6057 - precision_4: 0.6613 - recall_4: 0.5420
# Epoch 18/300
# 92/92 [==============================] - 1s 6ms/step - loss: 1.1033 - accuracy: 0.6320 - precision_4: 0.6803 - recall_4: 0.5604
# Epoch 19/300
# 92/92 [==============================] - 1s 7ms/step - loss: 1.0731 - accuracy: 0.6453 - precision_4: 0.6880 - recall_4: 0.5754
# Epoch 20/300
# 92/92 [==============================] - 1s 7ms/step - loss: 1.0175 - accuracy: 0.6627 - precision_4: 0.7053 - recall_4: 0.5975
# Epoch 21/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.9934 - accuracy: 0.6722 - precision_4: 0.7046 - recall_4: 0.6054
# Epoch 22/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.9669 - accuracy: 0.6866 - precision_4: 0.7236 - recall_4: 0.6170
# Epoch 23/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.9564 - accuracy: 0.6893 - precision_4: 0.7242 - recall_4: 0.6214
# Epoch 24/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.9416 - accuracy: 0.6907 - precision_4: 0.7249 - recall_4: 0.6337
# Epoch 25/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.9015 - accuracy: 0.6988 - precision_4: 0.7369 - recall_4: 0.6504
# Epoch 26/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.8974 - accuracy: 0.7070 - precision_4: 0.7412 - recall_4: 0.6497
# Epoch 27/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0
300
# 92/92 [==============================] - 1s 8ms/step - loss: 0.3686 - accuracy: 0.8762 - precision_4: 0.8837 - recall_4: 0.8683
# Epoch 123/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.3469 - accuracy: 0.8813 - precision_4: 0.8904 - recall_4: 0.8752
# Epoch 124/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.3360 - accuracy: 0.8885 - precision_4: 0.8978 - recall_4: 0.8810
# Epoch 125/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.3140 - accuracy: 0.8963 - precision_4: 0.9021 - recall_4: 0.8892
# Epoch 126/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.3205 - accuracy: 0.8936 - precision_4: 0.9000 - recall_4: 0.8898
# Epoch 127/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.3518 - accuracy: 0.8881 - precision_4: 0.8933 - recall_4: 0.8796
# Epoch 128/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.3383 - accuracy: 0.8857 - precision_4: 0.8954 - recall_4: 0.8789
# Epoch 129/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.3341 - accuracy: 0.8946 - precision_4: 0.9017 - recall_4: 0.8888
# Epoch 130/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.3200 - accuracy: 0.8909 - precision_4: 0.8951 - recall_4: 0.8847
# Epoch 131/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.4447 - accuracy: 0.8533 - precision_4: 0.8613 - recall_4: 0.8469
# Epoch 132/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.3182 - accuracy: 0.8915 - precision_4: 0.8998 - recall_4: 0.8851
# Epoch 133/300
# 92/92 [==============================] - 1s 8ms/step - loss: 0.3247 - accuracy: 0.8922 - precision_4: 0.8977 - recall_4: 0.8861
# Epoch 134/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.3107 - accuracy: 0.9004 - precision_4: 0.9056 - recall_4: 0.8936
# Epoch 135/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.2922 - accuracy: 0.9062 - precision_4: 0.9126 - recall_4: 0.9008
# Epoch 136/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.3521 - accuracy: 0.8827 - precision_4: 0.8898 - recall_4: 0.8731
# Epoch 137/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.2857 - accuracy: 0.9076 - precision_4: 0.9123 - recall_4: 0.9014
# Epoch 138/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.2786 - accuracy: 0.9062 - precision_4: 0.9112 - recall_4: 0.8994
# Epoch 139/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.2737 - accuracy: 0.9089 - precision_4: 0.9138 - recall_4: 0.9035
# Epoch 140/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.3309 - accuracy: 0.8953 - precision_4: 0.9002 - recall_4: 0.8919
# Epoch 141/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.2769 - accuracy: 0.9069 - precision_4: 0.9088 - recall_4: 0.9011
# Epoch 142/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.3036 - accuracy: 0.8994 - precision_4: 0.9041 - recall_4: 0.8939
# Epoch 143/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.3045 - accuracy: 0.9014 - precision_4: 0.9059 - recall_4: 0.8932
# Epoch 144/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.2679 - accuracy: 0.9123 - precision_4: 0.9183 - recall_4: 0.9083
# Epoch 145/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.2969 - accuracy: 0.9059 - precision_4: 0.9101 - recall_4: 0.9008
# Epoch 146/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.2792 - accuracy: 0.9069 - precision_4: 0.9101 - recall_4: 0.9008
# Epoch 147/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.2625 - accuracy: 0.9151 - precision_4: 0.9184 - recall_4: 0.9093
# Epoch 148/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.2688 - accuracy: 0.9151 - precision_4: 0.9180 - recall_4: 0.9083
# Epoch 149/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.3187 - accuracy: 0.9001 - precision_4: 0.9029 - recall_4: 0.8943
# Epoch 150/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.2791 - accuracy: 0.9093 - precision_4: 0.9143 - recall_4: 0.9055
# Epoch 151/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.2682 - accuracy: 0.9141 - precision_4: 0.9164 - recall_4: 0.9083
# Epoch 152/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.2471 - accuracy: 0.9161 - precision_4: 0.9190 - recall_4: 0.9127
# Epoch 153/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.2709 - accuracy: 0.9151 - precision_4: 0.9191 - recall_4: 0.9103
# Epoch 154/300
# 92/92 [==============================] - 1s 7ms/step - loss: 0.
300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.1595 - accuracy: 0.9437 - precision_4: 0.9450 - recall_4: 0.9430
# Epoch 217/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.3152 - accuracy: 0.9185 - precision_4: 0.9207 - recall_4: 0.9151
# Epoch 218/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.2190 - accuracy: 0.9250 - precision_4: 0.9270 - recall_4: 0.9226
# Epoch 219/300
# 92/92 [==============================] - 1s 6ms/step - loss: 0.1839 - accuracy: 0.9359 - precision_4: 0.9377 - recall_4: 0.9338

# %%
model24h.save('model24h.model')
# Out:
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: model24h.model/assets
# INFO:tensorflow:Assets written to: model24h.model/assets

# %%
yp = model24h.predict(x_test)
yp_class = np.round(yp)
score = model24h.evaluate(x_test, y_test, verbose=0)
cmatrix = confusion_matrix(np.argmax(y_test, axis=1), np.argmax(yp_class, axis=1))

# print(f"Accuracy {score[1]*100:.2f}%")

f1 = 2 *(score[2]*score[3]) / (score[3]+score[3])

print(f"Accuracy:  {score[1]*100:.2f}%")
print(f"Precision: {score[2]*100:.2f}%")
print(f"Recall:    {score[3]*100:.2f}%")
print(f"Recall:    {f1*100:.2f}%")
# Out:
# 23/23 [==============================] - 0s 2ms/step
# Accuracy:  93.73%
# Precision: 93.96%
# Recall:    93.32%
# Recall:    93.96%

# %%
plt.figure(figsize=(12, 12))
sns.set(font_scale=1.8)
sns.heatmap(cmatrix, annot=True, xticklabels=sorted_labels, yticklabels=sorted_labels, annot_kws={"size": 20}, cmap="Blues", fmt="g")
plt.xlabel('Predicted', fontsize = 20, weight='bold')
plt.ylabel('Actual', fontsize = 20, weight='bold')
# plt.title(f'Forecast: {nsteps} hour ahead')
plt.savefig('RNN-4states-24h-cmatrix.png')

# %%
plt.savefig('RNN-4states-24h-cmatrix.png');

# %%
len(model24h_hist.history['loss'])
# Out:
# 219

# %%
matplotlib.rc_file_defaults()

plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.plot(model24h_hist.history['loss'])
plt.xlabel('Epoch\n$(a)$')
plt.ylabel('Loss (cross-entropy)')
plt.grid()
plt.xticks( (1,50,100,150,200) )
plt.ylim(0,2)
plt.yticks((0,.5,1,1.5,2))
plt.subplot(1,2,2)
plt.plot(model24h_hist.history['accuracy'])
plt.xlabel('Epoch\n$(b)$')
plt.ylabel('Accuracy')
plt.grid()
plt.xticks( (1,50,100,150,200) )
plt.ylim(0,1)
plt.yticks( (0,.25, .50, .75, 1.00))

plt.subplots_adjust(bottom=0.15)

plt.savefig('RNN-4states-training.png')

# %%
from sklearn.metrics import roc_curve, auc, roc_auc_score

c_label = {0:'healthy', 1:'uncertain', 2:'stress', 3:'recovery'}
label_colors = { 0:'green', 1:'gray', 2:'red', 3:'blue'}

matplotlib.rc_file_defaults()

fig, (ax0, ax1) = plt.subplots(1,2, figsize = (12, 5))

for idx in (0, 1, 2, 3):
    fpr, tpr, thresholds = roc_curve(y_test[:,idx], yp[:,idx])
    label = f"{c_label[idx]} (AUC={auc(fpr, tpr):.3f})"
    ax0.plot(fpr, tpr, '-', c=label_colors[idx], label=label)
    
ax0.set_xlabel('False Positive ratio\n$(a)$')
ax0.set_xticks( (0, 0.25, .5, .75, 1.0))
ax0.set_ylabel('True Positive  ratio')
ax0.set_yticks( (0, 0.25, .5, .75, 1.0))
ax0.set_title(f"ROC curves (full model)")
ax0.legend()

ax0.grid()

ax1.plot(fpr_keras2, tpr_keras2, c='red', label=f"stress (AUC={auc_keras2:.3f})")
ax1.grid()
ax1.set_xlabel('False Positive ratio\n$(b)$')
ax1.set_xticks( (0, 0.25, .5, .75, 1.0))
ax1.set_ylabel('True Positive  ratio')
ax1.set_yticks( (0, 0.25, .5, .75, 1.0))

# ax1.annotate(f"AUC={auc_keras2:.3f}", xy =[0.8, 0.057])
ax1.set_title("ROC curve (simplified model)")
ax1.legend()

plt.subplots_adjust(bottom=0.15)

plt.savefig('RNN-24h-ROC.png');

# %% [markdown]
# ### KFold cross validation

# %%
kf = StratifiedKFold(n_splits = 5, random_state = 7, shuffle = True) 
# kf = KFold(n_splits = 5, random_state = 7, shuffle = True)

# %%
weights= {0:1,1:1,2:4,3:1}

scores4 = list()
fold_id=1

for train, test in kf.split(X, Y2):
    x_train = X[train,]
    y_train = Y[train,]
    x_test = X[test,]
    y_test = Y[test,]
    
    sc = StandardScaler()
    sc.fit(x_train)

    x_train = sc.transform(x_train)
    x_test = sc.transform(x_test)
    
    print(f"\t processing fold {fold_id}")
    
    model24hf = tf.keras.Sequential()
    model24hf.add(layers.LSTM(nLSTMs, activation='relu', input_shape=(X.shape[1], 1)))
#     model24hf.add(layers.Dense(4, activation='relu'))
    model24hf.add(layers.Dense(Y.shape[1], activation='softmax'))
    model24hf.compile(optimizer=tf.keras.optimizers.Adam(), loss='categorical_crossentropy', 
                 metrics =['accuracy', tf.keras.metrics.Precision(),tf.keras.metrics.Recall() ])
    

    model24h_hist = model24hf.fit(x_train, y_train, class_weight=weights, epochs=nepochs, callbacks=[callback], verbose=0)
    
    yp = model24hf.predict(x_test, verbose=0)
    yp_class = np.round(yp)
    score = model24hf.evaluate(x_test, y_test, verbose=0)


    
    scores4.append( (score, model24hf, class_hist))
    
    fold_id = fold_id + 1
    
print('\t done')
# Out:
# 	 processing fold 1
# 	 processing fold 2
# 	 processing fold 3
# 	 processing fold 4
# 	 processing fold 5
# 	 done

# %%
metric = ('accuracy', 'precison', 'recall','f-measure')

for i in (1,2,3):
    l=[ x[0][i]*100 for x in scores4 ] 
    print(f"{metric[i-1]:10} {np.mean(l):.4}  {np.std(l):.4}")

f1 = [ 2*x[0][2]*x[0][3]/(x[0][2]+x[0][3])*100 for x in scores4 ]

print(f"{metric[3]:10} {np.mean(f1)}  {np.std(f1)}")
# Out:
# accuracy   87.81  2.801
# precison   88.41  2.727
# recall     87.29  3.084
# f-measure  87.84413125091484  2.903665390004658

# %% [markdown]
# ### 24 hours forcasting (2 states)

# %%
nahead = 4*3
test_th = 0.2

nLSTM=20

X, Y, Y2 = getTensors(data_lagged, 'target', nahead)

model24h2 = tf.keras.Sequential()
model24h2.add(layers.LSTM(nLSTM, activation='relu', input_shape=(X.shape[1], 1)))
model24h2.add(layers.Dense(1, activation='sigmoid'))
model24h2.compile(optimizer=tf.keras.optimizers.Adam(), loss='binary_crossentropy', metrics =['accuracy', tf.keras.metrics.Precision(),tf.keras.metrics.Recall() ])

model24h2.summary()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_10 (LSTM)              (None, 20)                1760
#
#  dense_10 (Dense)            (None, 1)                 21
#
# =================================================================
# Total params: 1,781
# Trainable params: 1,781
# Non-trainable params: 0
# _________________________________________________________________

# %%
weights = {0:1, 1:1}

(x_train, x_test, y_train, y_test) = train_test_split(X, Y2, test_size=test_th, shuffle=True)

sc = StandardScaler()
sc.fit(x_train)

x_train = sc.transform(x_train)
x_test = sc.transform(x_test)

# %%
class_hist_model24h2 = model24h2.fit(x_train, y_train.reshape(-1,1), class_weight=weights, epochs=nepochs, callbacks=[callback], verbose=1)
# Out:
# Epoch 1/300
# 96/96 [==============================] - 2s 6ms/step - loss: 0.5832 - accuracy: 0.8122 - precision_10: 0.0000e+00 - recall_10: 0.0000e+00
# Epoch 2/300
# 96/96 [==============================] - 1s 6ms/step - loss: 0.4228 - accuracy: 0.8194 - precision_10: 0.5902 - recall_10: 0.1254
# Epoch 3/300
# 96/96 [==============================] - 1s 6ms/step - loss: 0.3993 - accuracy: 0.8342 - precision_10: 0.6516 - recall_10: 0.2509
# Epoch 4/300
# 96/96 [==============================] - 1s 6ms/step - loss: 0.3929 - accuracy: 0.8384 - precision_10: 0.6587 - recall_10: 0.2892
# Epoch 5/300
# 96/96 [==============================] - 1s 6ms/step - loss: 0.3858 - accuracy: 0.8361 - precision_10: 0.6527 - recall_10: 0.2718
# Epoch 6/300
# 96/96 [==============================] - 1s 6ms/step - loss: 0.3777 - accuracy: 0.8407 - precision_10: 0.6719 - recall_10: 0.2962
# Epoch 7/300
# 96/96 [==============================] - 1s 6ms/step - loss: 0.3739 - accuracy: 0.8423 - precision_10: 0.6983 - recall_10: 0.2822
# Epoch 8/300
# 96/96 [==============================] - 1s 6ms/step - loss: 0.3675 - accuracy: 0.8436 - precision_10: 0.7051 - recall_10: 0.2875
# Epoch 9/300
# 96/96 [==============================] - 1s 7ms/step - loss: 0.3642 - accuracy: 0.8371 - precision_10: 0.6827 - recall_10: 0.2474
# Epoch 10/300
# 96/96 [==============================] - 1s 7ms/step - loss: 0.3631 - accuracy: 0.8417 - precision_10: 0.6786 - recall_10: 0.2979
# Epoch 11/300
# 96/96 [==============================] - 1s 6ms/step - loss: 0.3531 - accuracy: 0.8430 - precision_10: 0.7061 - recall_10: 0.2805
# Epoch 12/300
# 96/96 [==============================] - 1s 6ms/step - loss: 0.3469 - accuracy: 0.8417 - precision_10: 0.6718 - recall_10: 0.3066
# Epoch 13/300
# 96/96 [==============================] - 1s 6ms/step - loss: 0.3484 - accuracy: 0.8420 - precision_10: 0.6827 - recall_10: 0.2962
# Epoch 14/300
# 96/96 [==============================] - 1s 7ms/step - loss: 0.3407 - accuracy: 0.8449 - precision_10: 0.6894 - recall_10: 0.3171
# Epoch 15/300
# 96/96 [==============================] - 1s 6ms/step - loss: 0.3265 - accuracy: 0.8443 - precision_10: 0.6775 - recall_10: 0.3258
# Epoch 16/300
# 96/96 [==============================] - 1s 6ms/step - loss: 0.3123 - accuracy: 0.8489 - precision_10: 0.7000 - recall_10: 0.3415
# Epoch 17/300
# 96/96 [==============================] - 1s 7ms/step - loss: 0.3257 - accuracy: 0.8420 - precision_10: 0.6522 - recall_10: 0.3397
# Epoch 18/300
# 96/96 [==============================] - 1s 7ms/step - loss: 0.3049 - accuracy: 0.8495 - precision_10: 0.7065 - recall_10: 0.3397
# Epoch 19/300
# 96/96 [==============================] - 1s 8ms/step - loss: 0.3001 - accuracy: 0.8525 - precision_10: 0.7113 - recall_10: 0.3606
# Epoch 20/300
# 96/96 [==============================] - 1s 7ms/step - loss: 0.2910 - accuracy: 0.8551 - precision_10: 0.7148 - recall_10: 0.3798
# Epoch 21/300
# 96/96 [==============================] - 1s 6ms/step - loss: 0.2879 - accuracy: 0.8570 - precision_10: 0.6963 - recall_10: 0.4233
# Epoch 22/300
# 96/96 [==============================] - 1s 6ms/step - loss: 0.2797 - accuracy: 0.8606 - precision_10: 0.6937 - recall_10: 0.4617
# Epoch 23/300
# 96/96 [==============================] - 1s 7ms/step - loss: 0.2828 - accuracy: 0.8597 - precision_10: 0.7031 - recall_10: 0.4373
# Epoch 24/300
# 96/96 [==============================] - 1s 8ms/step - loss: 0.2734 - accuracy: 0.8613 - precision_10: 0.6974 - recall_10: 0.4617
# Epoch 25/300
# 96/96 [==============================] - 1s 7ms/step - loss: 0.2634 - accuracy: 0.8695 - precision_10: 0.7088 - recall_10: 0.5174
# Epoch 26/300
# 96/96 [==============================] - 1s 6ms/step - loss: 0.2663 - accuracy: 0.8633 - precision_10: 0.6765 - recall_10: 0.5209
# Epoch 27/300
# 96/96 [==============================] - 1s 6ms/step - loss: 0.2547 - accuracy: 0.8714 - precision_10: 0.7160 - recall_10: 0.5226
# Epoch 28/300
# 96/96 [==============================] - 1s 6ms/step - loss: 0.2583 - accuracy: 0.8708 - precision_10: 0.6993 - recall_10: 0.5470
# Epoch 29/300
# 96/96 [==============================] - 1s 6ms/step - loss: 0.2720 - accuracy: 0.8705 - precision_10: 0.7214 - recall_10: 0.5052
# Epoch 30/300
# 96/96 [==============================] - 1s 6ms/step - loss: 0.2480 - accuracy: 0.8760 - precision_10: 0.7106 - recall_10: 0.5732
# Epoch 31/300
# 96/96 [==============================] - 1s 6ms/step - loss: 0.2587 - accuracy: 0.8695 - precision_10: 0.6890 - recall_10: 0.5557
# Epoch 32/300
# 96/96 [==============================] - 1s 7ms/step - loss: 0.2442 - accuracy: 0.8793 - precision_10: 0.7293 - recall_10: 0.5679
# Epoch 33/300
# 96/96 [==============================] - 1s 7ms/step - loss: 0.2390 - accuracy: 0.8835 - precision_10: 0.7261 - recall_10: 0.6098
# Epoch 34/300
# 96/96 [==============================] - 1s 7ms/step - loss: 0.2353 - accuracy: 0.8829 - precision_10: 0.7126 - recall_10: 0.6307
# Epoch 35/300
# 96/96 [==============================] - 1s 6ms/step - loss: 0.2315 - accuracy: 0.8852 - precision_10: 0.7243 - recall_10: 0.6272
# Epoch 36/300
# 96/96 [==============================] - 1s 7ms/step - loss: 0.2250 - accuracy: 0.8885 - precision_10: 0.7245 - recall_10: 0.6551
# Epoch 37/300
# 96/96 [==============================] - 1s 7ms/step - loss: 0.2553 - accuracy: 0.8763 - precision_10: 0.6992 - recall_10: 0.5993
# Epoch 38/300
# 96/96 [==============================] - 1s 7ms/step - loss: 0.2269 - accuracy: 0.8865 - precision_10: 0.7379 - recall_10: 0.6132
# Epoch 39/300
# 96/96 [==============================] - 1s 7ms/step - loss: 0.2203 - accuracy: 0.8894 - precision_10: 0.7278 - recall_10: 0.6568
# Epoch 40/300
# 96/96 [==============================] - 1s 7ms/step - loss: 0.2197 - accuracy: 0.8937 - precision_10: 0.7327 - recall_10: 0.6829
# Epoch 41/300
# 96/96 [==============================] - 1s 7ms/step - loss: 0.2201 - accuracy: 0.8917 - precision_10: 0.7288 - recall_10: 0.6742
# Epoch 42/300
# 96/96 [==============================] - 1s 7ms/step - loss: 0.2219 - accuracy: 0.8937 - precision_10: 0.7284 - recall_10: 0.6916
# Epoch 43/300
# 96/96 [==============================] - 1s 7ms/step - loss: 0.2147 - accuracy: 0.8996 - precision_10: 0.7432 - recall_10: 0.7108
# Epoch 44/300
# 96/96 [==============================] - 1s 7ms/step - loss: 0.2344 - accuracy: 0.8885 - precision_10: 0.6938 - recall_10: 0.7265
# Epoch 45/300
# 96/96 [==============================] - 1s 7ms/step - loss: 0.2753 - accuracy: 0.8682 - precision_10: 0.6641 - recall_10: 0.6028
# Epoch 46/300
# 96/96 [==============================] - 1s 7ms/step - loss: 0.2397 - accuracy: 0.8855 - precision_10: 0.7267 - recall_10: 0.6254
# Epoch 47/300
# 96/96 [==============================] - 1s 7ms/step - loss: 0.2316 - accuracy: 0.8871 - precision_10: 0.7241 - recall_10: 0.6446
# Epoch 48/300
# 96/96 [==============================] - 1s 7ms/step - loss: 0.2203 - accuracy: 0.8934 - precision_10: 0.7441 - recall_10: 0.6585
# Epoch 49/300
# 96/96 [==============================] - 1s 7ms/step - loss: 0.2164 - accuracy: 0.8973 - precision_10: 0.7453 - recall_10: 0.6882
# Epoch 50/300
# 96/96 [==============================] - 1s 7ms/step - loss: 0.2216 - accuracy: 0.8917 - precision_10: 0.7271 - recall_10: 0.6777
# Epoch 51/300
# 96/96 [==============================] - 1s 7ms/step - loss: 0.2178 - accuracy: 0.8966 - precision_10: 0.7443 - recall_10: 0.6847
# Epoch 52/300
# 96/96 [==============================] - 1s 7ms/step - loss: 0.2057 - accuracy: 0.8996 - precision_10: 0.7486 - recall_10: 0.7003
# Epoch 53/300
# 96/96 [==============================] - 1s 7ms/step - loss: 0.2044 - accuracy: 0.8999 - precision_10: 0.7393 - recall_10: 0.7213
# Epoch 54/300
# 96/96 [==============================] - 1s 8ms/step - loss: 0.2036 - accuracy: 0.9032 - precision_10: 0.7584 - recall_10: 0.7108
# Epoch 55/300
# 96/96 [==============================] - 1s 7ms/step - loss: 0.2049 - accuracy: 0.9012 - precision_10: 0.7420 - recall_10: 0.7265
# Epoch 56/300
# 96/96 [==============================] - 1s 7ms/step - loss: 0.1978 - accuracy: 0.9032 - precision_10: 0.7439 - recall_10: 0.7387
# Epoch 57/300
# 96/96 [==============================] - 1s 7ms/step - loss: 0.2074 - accuracy: 0.9019 - precision_10: 0.7395 - recall_10: 0.7369
# Epoch 58/300
# 96/96 [==============================] - 1s 8ms/step - loss: 0.2026 - accuracy: 0.8999 - precision_10: 0.7376 - recall_10: 0.7247
# Epoch 59/300
# 96/96 [==============================] - 1s 7ms/step - loss: 0.1921 - accuracy: 0.9078 - precision_10: 0.7544 - recall_10: 0.7544
# Epoch 60/300
# 96/96 [==============================] - 1s 8ms/step - loss: 0.1912 - accuracy: 0.9035 - precision_10: 0.7443 - recall_10: 0.7404
# Epoch 61/300
# 96/96 [==============================] - 1s 7ms/step - loss: 0.1963 - accuracy: 0.9064 - precision_10: 0.7562 - recall_10: 0.7404
# Epoch 62/300
# 96/96 [==============================] - 1s 7ms/step - loss: 0.2068 - accuracy: 0.8979 - precision_10: 0.7306 - recall_10: 0.7230
# Epoch 63/300
# 96/96 [==============================] - 1s 7ms/step - loss: 0.1945 - accuracy: 0.9084 - precision_10: 0.7534 - recall_10: 0.7613
# Epoch 64/300
# 96/96 [==============================] - 1s 7ms/step - loss: 0.1876 - accuracy: 0.9071 - precision_10: 0.7500 - recall_10: 0.7578
# Epoch 65/300
# 96/96 [==============================] - 1s 7ms/step - loss: 0.1939 - accuracy: 0.9071 - precision_10: 0.7509 - recall_10: 0.7561
# Epoch 66/300
# 96/96 [==============================] - 1s 7ms/step - loss: 0.1895 - accuracy: 0.9084 - precision_10: 0.7500 - recall_10: 0.7683
# Epoch 67/300
# 96/96 [==============================] - 1s 7ms/step - loss: 0.1882 - accuracy: 0.9038 - precision_10: 0.7414 - recall_10: 0.7491
# Epoch 68/300
# 96/96 [==============================] - 1s 7ms/step - loss: 0.1849 - accuracy: 0.9064 - precision_10: 0.7457 - recall_10: 0.7613
# Epoch 69/300
# 96/96 [==============================] - 1s 7ms/step - loss: 0.1884 - accuracy: 0.9035 - precision_10: 0.7385 - recall_10: 0.7526
# Epoch 70/300
# 96/96 [==============================] - 1s 7ms/step - loss: 0.1856 - accuracy: 0.9133 - precision_10: 0.7614 - recall_10: 0.7840
# Epoch 71/300
# 96/96 [==============================] - 1s 7ms/step - loss: 0.1786 - accuracy: 0.9140 - precision_10: 0.7695 - recall_10: 0.7735
# Epoch 72/300
# 96/96 [==============================] - 1s 7ms/step - loss: 0.1766 - accuracy: 0.9114 - precision_10: 0.7581 - recall_10: 0.7753
# Epoch 73/300
# 96/96 [==============================] - 1s 7ms/step - loss: 0.1830 - accuracy: 0.9133 - precision_10: 0.7696 - recall_10: 0.7683
# Epoch 74/300
# 96/96 [==============================] - 1s 6ms/step - loss: 0.1740 - accuracy: 0.9156 - precision_10: 0.7715 - recall_10: 0.7822
# Epoch 75/300
# 96/96 [==============================] - 1s 6ms/step - loss: 0.1695 - accuracy: 0.9159 - precision_10: 0.7719 - recall_10: 0.7840
# Epoch 76/300
# 96/96 [==============================] - 1s 6ms/step - loss: 0.1738 - accuracy: 0.9169 - precision_10: 0.7703 - recall_10: 0.7944
# Epoch 77/300
# 96/96 [==============================] - 1s 6ms/step - loss: 0.1772 - accuracy: 0.9169 - precision_10: 0.7703 - recall_10: 0.7944
# Epoch 78/300
# 96/96 [==============================] - 1s 6ms/step - loss: 0.1704 - accuracy: 0.9182 - precision_10: 0.7765 - recall_10: 0.7927
# Epoch 79/300
# 96/96 [==============================] - 1s 6ms/step - loss: 0.1718 - accuracy: 0.9192 - precision_10: 0.7884 - recall_10: 0.7787
# Epoch 80/300
# 96/96 [==============================] - 1s 6ms/step - loss: 0.1688 - accuracy: 0.9182 - precision_10: 0.7718 - recall_10: 0.8014
# Epoch 81/300
# 96/96 [==============================] - 1s 6ms/step - loss: 0.1645 - accuracy: 0.9182 - precision_10: 0.7736 - recall_10: 0.7979
# Epoch 82/300
# 96/96 [==============================] - 1s 6ms/step - loss: 0.1622 - accuracy: 0.9215 - precision_10: 0.7831 - recall_10: 0.8049
# Epoch 83/300
# 96/96 [==============================] - 1s 6ms/step - loss: 0.1626 - accuracy: 0.9159 - precision_10: 0.7682 - recall_10: 0.7909
# Epoch 84/300
# 96/96 [==============================] - 1s 5ms/step - loss: 0.1641 - accuracy: 0.9218 - precision_10: 0.7834 - recall_10: 0.8066
# Epoch 85/300
# 96/96 [==============================] - 1s 6ms/step - loss: 0.1597 - accuracy: 0.9215 - precision_10: 0.7811 - recall_10: 0.8084
# Epoch 86/300
# 96/96 [==============================] - 1s 6ms/step - loss: 0.1652 - accuracy: 0.9192 - precision_10: 0.7730 - recall_10: 0.8066
# Epoch 87/300
# 96/96 [==============================] - 1s 6ms/step - loss: 0.1728 - accuracy: 0.9133 - precision_10: 0.7650 - recall_10: 0.7770
# Epoch 88/300
# 96/96 [==============================] - 1s 6ms/step - loss: 0.1955 - accuracy: 0.9035 - precision_10: 0.7329 - recall_10: 0.7648
# Epoch 89/300
# 96/96 [==============================] - 1s 6ms/step - loss: 0.1700 - accuracy: 0.9199 - precision_10: 0.7851 - recall_10: 0.7892
# Epoch 90/300
# 96/96 [==============================] - 1s 6ms/step - loss: 0.1604 - accuracy: 0.9235 - precision_10: 0.7862 - recall_10: 0.8136
# Epoch 91/300
# 96/96 [==============================] - 1s 6ms/step - loss: 0.1544 - accuracy: 0.9225 - precision_10: 0.7813 - recall_10: 0.8153
# Epoch 92/300
# 96/96 [==============================] - 1s 6ms/step - loss: 0.1542 - accuracy: 0.9244 - precision_10: 0.7912 - recall_10: 0.8118
# Epoch 93/300
# 96/96 [==============================] - 1s 6ms/step - loss: 0.1550 - accuracy: 0.9228 - precision_10: 0.7826 - recall_10: 0.8153
# Epoch 94/300
# 96/96 [==============================] - 1s 6ms/step - loss: 0.1504 - accuracy: 0.9267 - precision_10: 0.8017 - recall_10: 0.8101
# Epoch 95/300
# 96/96 [==============================] - 1s 6ms/step - loss: 0.1489 - accuracy: 0.9307 - precision_10: 0.8078 - recall_10: 0.8275
# Epoch 96/300
# 96/96 [==============================] - 1s 6ms/step - loss: 0.1521 - accuracy: 0.9215 - precision_10: 0.7783 - recall_10: 0.8136
# Epoch 97/300
# 96/96 [==============================] - 1s 6ms/step - loss: 0.1544 - accuracy: 0.9218 - precision_10: 0.7825 - recall_10: 0.8084
# Epoch 98/300
# 96/96 [==============================] - 1s 6ms/step - loss: 0.1460 - accuracy: 0.9290 - precision_10: 0.7950 - recall_10: 0.8380
# Epoch 99/300
# 96/96 [==============================] - 1s 6ms/step - loss: 0.1418 - accuracy: 0.9323 - precision_10: 0.8137 - recall_10: 0.8293
# Epoch 100/300
# 96/96 [==============================] - 1s 6ms/step - loss: 0.1426 - accuracy: 0.9300 - precision_10: 0.8020 - recall_10: 0.8328
# Epoch 101/300
# 96/96 [==============================] - 1s 6ms/step - loss: 0.1519 - accuracy: 0.9248 - precision_10: 0.7876 - recall_10: 0.8206
# Epoch 102/300
# 96/96 [==============================] - 1s 6ms/step - loss: 0.1454 - accuracy: 0.9280 - precision_10: 0.7921 - recall_10: 0.8362
# Epoch 103/300
# 96/96 [==============================] - 1s 7ms/step - loss: 0.1415 - accuracy: 0.9307 - precision_10: 0.7997 - recall_10: 0.8415
# Epoch 104/300
# 96/96 [==============================] - 1s 7ms/step - loss: 0.1340 - accuracy: 0.9362 - precision_10: 0.8143 - recall_10: 0.8554
# Epoch 105/300
# 96/96 [==============================] - 1s 7ms/step - loss: 0.1398 - accuracy: 0.9342 - precision_10: 0.8114 - recall_10: 0.8467
# Epoch 106/300
# 96/96 [==============================] - 1s 7ms/step - loss: 0.1487 - accuracy: 0.9310 - precision_10: 0.8092 - recall_10: 0.8275
# Epoch 107/300
# 96/96 [==============================] - 1s 7ms/step - loss: 0.1419 - accuracy: 0.9323 - precision_10: 0.8137 - recall_10: 0.8293
# Epoch 108/300
# 96/96 [==============================] - 1s 7ms/step - loss: 0.1358 - accuracy: 0.9356 - precision_10: 0.8190 - recall_10: 0.8432
# Epoch 109/300
# 96/96 [==============================] - 1s 7ms/step - loss: 0.1376 - accuracy: 0.9342 - precision_10: 0.8177 - recall_10: 0.8362
# Epoch 110/300
# 96/96 [==============================] - 1s 6ms/step - loss: 0.1359 - accuracy: 0.9323 - precision_10: 0.8115 - recall_10: 0.8328
# Epoch 111/300
# 96/96 [==============================] - 1s 6ms/step - loss: 0.1591 - accuracy: 0.9277 - precision_10: 0.7966 - recall_10: 0.8258
# Epoch 112/300
# 96/96 [==============================] - 1s 6ms/step - loss: 0.1484 - accuracy: 0.9267 - precision_10: 0.7936 - recall_10: 0.8240
# Epoch 113/300
# 96/96 [==============================] - 1s 6ms/step - loss: 0.1343 - accuracy: 0.9362 - precision_10: 0.8122 - recall_10: 0.8589
# Epoch 114/300
# 96/96 [==============================] - 1s 6ms/step - loss: 0.1274 - accuracy: 0.9388 - precision_10: 0.8263 - recall_10: 0.8537
# Epoch 115/300
# 96/96 [==============================] - 1s 6ms/step - loss: 0.1254 - accuracy: 0.9421 - precision_10: 0.8336 - recall_10: 0.8641
# Epoch 116/300
# 96/96 [==============================] - 1s 6ms/step - loss: 0.1246 - accuracy: 0.9405 - precision_10: 0.8356 - recall_10: 0.8502
# Epoch 117/300
# 96/96 [==============================] - 1s 6ms/step - loss: 0.1259 - accuracy: 0.9385 - precision_10: 0.8238 - recall_10: 0.8554
# Epoch 118/300
# 96/96 [==============================] - 1s 6ms/step - loss: 0.1297 - accuracy: 0.9392 - precision_10: 0.8266 - recall_10: 0.8554
# Epoch 119/300
# 96/96 [==============================] - 1s 6ms/step - loss: 0.1208 - accuracy: 0.9421 - precision_10: 0.8347 - recall_10: 0.8624
# Epoch 120/300
# 96/96 [==============================] - 1s 6ms/step - loss: 0.1256 - accuracy: 0.9382 - precision_10: 0.8268 - recall_10: 0.8484
# Epoch 121/300
# 96/96 [==============================] - 1s 6ms/step - loss: 0.1206 - accuracy: 0.9411 - precision_10: 0.8350 - recall_10: 0.8554
# Epoch 122/300
# 96/96 [==============================] - 1s 6ms/step - loss: 0.1180 - accuracy: 0.9437 - precision_10: 0.8339 - recall_10: 0.8746
# Epoch 123/300
# 96/96 [==============================] - 1s 6ms/step - loss: 0.1225 - accuracy: 0.9401 - precision_10: 0.8353 - recall_10: 0.8484
# Epoch 124/300
# 96/96 [==============================] - 1s 6ms/step - loss: 0.1264 - accuracy: 0.9437 - precision_10: 0.8361 - recall_10: 0.8711
# Epoch 125/300
# 96/96 [==============================] - 1s 6ms/step - loss: 0.1254 - accuracy: 0.9428 - precision_10: 0.8287 - recall_10: 0.8763
# Epoch 126/300
# 96/96 [==============================] - 1s 6ms/step - loss: 0.1158 - accuracy: 0.9437 - precision_10: 0.8454 - recall_10: 0.8571
# Epoch 127/300
# 96/96 [==============================] - 1s 6ms/step - loss: 0.1165 - accuracy: 0.9450 - precision_10: 0.8383 - recall_10: 0.8763
# Epoch 128/300
# 96/96 [==============================] - 1s 6ms/step - loss: 0.1338 - accuracy: 0.9303 - precision_10: 0.8085 - recall_10: 0.8240
# Epoch 129/300
# 96/96 [==============================] - 1s 6ms/step - loss: 0.1267 - accuracy: 0.9395 - precision_10: 0.8371 - recall_10: 0.8415
# Epoch 130/300
# 96/96 [==============================] - 1s 6ms/step - loss: 0.1206 - accuracy: 0.9424 - precision_10: 0.8350 - recall_10: 0.8641
# Epoch 131/300
# 96/96 [==============================] - 1s 6ms/step - loss: 0.1174 - accuracy: 0.9431 - precision_10: 0.8367 - recall_10: 0.8659
# Epoch 132/300
# 96/96 [==============================] - 1s 6ms/step - loss: 0.1138 - accuracy: 0.9437 - precision_10: 0.8502 - recall_10: 0.8502
# Epoch 133/300
# 96/96 [==============================] - 1s 7ms/step - loss: 0.1125 - accuracy: 0.9444 - precision_10: 0.8367 - recall_10: 0.8746
# Epoch 134/300
# 96/96 [==============================] - 1s 7ms/step - loss: 0.1161 - accuracy: 0.9464 - precision_10: 0.8405 - recall_10: 0.8815
# Epoch 135/300
# 96/96 [==============================] - 1s 7ms/step - loss: 0.1104 - accuracy: 0.9483 - precision_10: 0.8574 - recall_10: 0.8693
# Epoch 136/300
# 96/96 [==============================] - 1s 7ms/step - loss: 0.1233 - accuracy: 0.9401 - precision_10: 0.8297 - recall_10: 0.8571
# Epoch 137/300
# 96/96 [==============================] - 1s 7ms/step - loss: 0.1094 - accuracy: 0.9470 - precision_10: 0.8492 - recall_10: 0.8728
# Epoch 138/300
# 96/96 [==============================] - 1s 7ms/step - loss: 0.1084 - accuracy: 0.9486 - precision_10: 0.8469 - recall_10: 0.8868
# Epoch 139/300
# 96/96 [==============================] - 1s 6ms/step - loss: 0.1117 - accuracy: 0.9500 - precision_10: 0.8491 - recall_10: 0.8920
# Epoch 140/300
# 96/96 [==============================] - 1s 6ms/step - loss: 0.1259 - accuracy: 0.9405 - precision_10: 0.8278 - recall_10: 0.8624
# Epoch 141/300
# 96/96 [==============================] - 1s 6ms/step - loss: 0.1147 - accuracy: 0.9398 - precision_10: 0.8316 - recall_10: 0.8519
# Epoch 142/300
# 96/96 [==============================] - 1s 7ms/step - loss: 0.1059 - accuracy: 0.9486 - precision_10: 0.8504 - recall_10: 0.8815
# Epoch 143/300
# 96/96 [==============================] - 1s 7ms/step - loss: 0.1048 - accuracy: 0.9503 - precision_10: 0.8482 - recall_10: 0.8955
# Epoch 144/300
# 96/96 [==============================] - 1s 7ms/step - loss: 0.1111 - accuracy: 0.9480 - precision_10: 0.8511 - recall_10: 0.8763
# Epoch 145/300
# 96/96 [==============================] - 1s 7ms/step - loss: 0.1208 - accuracy: 0.9444 - precision_10: 0.8367 - recall_10: 0.8746
# Epoch 146/300
# 96/96 [==============================] - 1s 7ms/step - loss: 0.1153 - accuracy: 0.9441 - precision_10: 0.8398 - recall_10: 0.8676
# Epoch 147/300
# 96/96 [==============================] - 1s 7ms/step - loss: 0.1073 - accuracy: 0.9490 - precision_10: 0.8483 - recall_10: 0.8868
# Epoch 148/300
# 96/96 [==============================] - 1s 7ms/step - loss: 0.1076 - accuracy: 0.9496 - precision_10: 0.8559 - recall_10: 0.8798
# Epoch 149/300
# 96/96 [==============================] - 1s 7ms/step - loss: 0.1272 - accuracy: 0.9447 - precision_10: 0.8403 - recall_10: 0.8711
# Epoch 150/300
# 96/96 [==============================] - 1s 7ms/step - loss: 0.2442 - accuracy: 0.8894 - precision_10: 0.7042 - recall_10: 0.7091
# Epoch 151/300
# 96/96 [==============================] - 1s 7ms/step - loss: 0.1594 - accuracy: 0.9254 - precision_10: 0.8024 - recall_10: 0.7997
# Epoch 152/300
# 96/96 [==============================] - 1s 7ms/step - loss: 0.1282 - accuracy: 0.9378 - precision_10: 0.8221 - recall_10: 0.8537
# Epoch 153/300
# 96/96 [==============================] - 1s 7ms/step - loss: 0.1194 - accuracy: 0.9444 - precision_10: 0.8389 - recall_10: 0.8711

# %%
yp = model24h2.predict(x_test)
yp_predict_class = np.round(yp)
score = model24h2.evaluate(x_test, y_test, verbose=0)

# print(f"Accuracy {score[1]*100:.2f}%")
f1 = 2 *(score[2]*score[3]) / (score[3]+score[3])

print(f"Accuracy:  {score[1]*100:.2f}%")
print(f"Precision: {score[2]*100:.2f}%")
print(f"Recall:    {score[3]*100:.2f}%")
print(f"F1:        {f1*100:.2f}%")


print(confusion_matrix(y_test, yp_predict_class))
# Out:
# 24/24 [==============================] - 0s 3ms/step
# Accuracy:  93.33%
# Precision: 77.18%
# Recall:    87.12%
# F1:        77.18%
# [[599  34]
#  [ 17 115]]

# %% [markdown]
# ### K-Fold cross validation

# %%
kf = StratifiedKFold(n_splits = 5, random_state = 7, shuffle = True) 
# kf = KFold(n_splits = 5, random_state = 7, shuffle = True)

# %%
scores2 = list()

fold_id=1

for train, test in kf.split(X, Y2):
    x_train = X[train,]
    y_train = Y2[train,]
    x_test = X[test,]
    y_test = Y2[test,]
    
    sc = StandardScaler()
    sc.fit(x_train)

    x_train = sc.transform(x_train)
    x_test = sc.transform(x_test)
    
    print(f"\t processing fold {fold_id}")
    
    model24h2f = tf.keras.Sequential()
    model24h2f.add(layers.LSTM(nLSTM, activation='relu', input_shape=(X.shape[1], 1)))
    model24h2f.add(layers.Dense(1, activation='sigmoid'))
    model24h2f.compile(optimizer=tf.keras.optimizers.Adam(), loss='binary_crossentropy', metrics =['accuracy', tf.keras.metrics.Precision(),tf.keras.metrics.Recall() ])
    class_hist = model24h2f.fit(x_train, y_train.reshape(-1,1), class_weight=weights, epochs=nepochs, callbacks=[callback], verbose=0)
    
    yp = model24h2f.predict(x_test, verbose=0)
    yp_predict_class = np.round(yp)
    score = model24h2f.evaluate(x_test, y_test, verbose=0)
    
    scores2.append( (score, model24h2f, class_hist))
    
    fold_id = fold_id + 1
    
print('\t done')
# Out:
# 	 processing fold 1
# 	 processing fold 2
# 	 processing fold 3
# 	 processing fold 4
# 	 processing fold 5
# 	 done

# %%
metric = ('accuracy', 'precison', 'recall','f-measure')

for i in (1,2,3):
    l=[ x[0][i]*100 for x in scores4 ] 
    print(f"{metric[i-1]:10} {np.mean(l):.4}  {np.std(l):.4}")

f1 = [ 2*x[0][2]*x[0][3]/(x[0][2]+x[0][3])*100 for x in scores2 ]

print(f"{metric[3]:10} {np.mean(f1)}  {np.std(f1)}")
# Out:
# accuracy   87.81  2.801
# precison   88.41  2.727
# recall     87.29  3.084
# f-measure  78.89214346016604  4.413942551607048

# %%
metric = ('accuracy', 'precison', 'recall','f-measure')
for i in (1,2,3):
    l=[ x[0][i]*100 for x in scores2 ] 
    print(f"{metric[i-1]:10} {np.mean(l):.4}  {np.std(l):.4}")

f1 = [ 2*x[0][2]*x[0][3]/(x[0][2]+x[0][3])*100 for x in scores2 ]

print(f"{metric[3]:10} {np.mean(f1):.4}  {np.std(f1):.4}")
# Out:
# accuracy   92.18  2.018
# precison   79.94  7.714
# recall     78.33  3.604
# f-measure  78.89  4.414
